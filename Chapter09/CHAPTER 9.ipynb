# %% [markdown]
# # Python Algorithmic Trading Cookbook

# %% [markdown]
# ## Chapter 9: Algorithmic Trading: Backtesting

# %% [markdown]
# This Jupyter Notebook is created using Python version 3.8.2

# %% [markdown]
# ----

# %% [markdown]
# ### Recipe 1: EMA-Regular-Order Strategy: Fetching the Strategy

# %%
from pyalgotrading.algobulls import AlgoBullsConnection

# %%
algobulls_connection = AlgoBullsConnection()

# %%
algobulls_connection.get_authorization_url()
# Out:
# Please login to this URL with your AlgoBulls credentials and get your developer access token: https://app.algobulls.com/user/login
# 'https://app.algobulls.com/user/login'

# %%
algobulls_connection.set_access_token('b4e0f923d085d48f4665a079d760d2bb94c33a94')

# %%
all_strategies = algobulls_connection.get_all_strategies()
all_strategies
# Out:
#                        strategyCode                 strategyName
# 0  49287246f9704bbcbad76ade9e2091d9   EMA Regular Order Strategy
# 1  4faf514fe096432b8e9f80f5951bd2ea  MACD Bracket Order Strategy

# %%
strategy_code1 = all_strategies.iloc[0]['strategyCode']
strategy_code1
# Out:
# '49287246f9704bbcbad76ade9e2091d9'

# %%
strategy_details1 = algobulls_connection.get_strategy_details(strategy_code1)
print(strategy_details1)
# Out:
# class StrategyEMARegularOrder(StrategyBase):
#
#     def __init__(self, *args, **kwargs):
#         super().__init__(*args, **kwargs)
#
#         self.timeperiod1 = self.strategy_parameters['timeperiod1']
#         self.timeperiod2 = self.strategy_parameters['timeperiod2']
#
#         self.main_order = None
#
#     def initialize(self):
#         self.main_order = {}
#
#     @staticmethod
#     def name():
#         return 'EMA Regular Order Strategy'
#
#     @staticmethod
#     def versions_supported():
#         return AlgoBullsEngineVersion.VERSION_3_2_0
#
#     def get_crossover_value(self, instrument):
#         hist_data = self.get_historical_data(instrument)
#         ema_x = talib.EMA(hist_data['close'], timeperiod=self.timeperiod1)
#         ema_y = talib.EMA(hist_data['close'], timeperiod=self.timeperiod2)
#         crossover_value = self.utils.crossover(ema_x, ema_y)
#         return crossover_value
#
#     def strategy_select_instruments_for_entry(self, candle, instruments_bucket):
#
#         selected_instruments_bucket = []
#         sideband_info_bucket = []
#
#         for instrument in instruments_bucket:
#             crossover_value = self.get_crossover_value(instrument)
#             if crossover_value == 1:
#                 selected_instruments_bucket.append(instrument)
#                 sideband_info_bucket.append({'action': 'BUY'})
#             elif crossover_value == -1:
#                 if self.strategy_mode is StrategyMode.INTRADAY:
#                     selected_instruments_bucket.append(instrument)
#                     sideband_info_bucket.append({'action': 'SELL'})
#
#         return selected_instruments_bucket, sideband_info_bucket
#
#     def strategy_enter_position(self, candle, instrument, sideband_info):
#         if sideband_info['action'] == 'BUY':
#             qty = self.number_of_lots * instrument.lot_size
#             self.main_order[instrument] = \
#                 self.broker.BuyOrderRegular(instrument=instrument,
#                                             order_code=BrokerOrderCodeConstants.INTRADAY,
#                                             order_variety=BrokerOrderVarietyConstants.MARKET,
#                                             quantity=qty)
#         elif sideband_info['action'] == 'SELL':
#             qty = self.number_of_lots * instrument.lot_size
#             self.main_order[instrument] = \
#                 self.broker.SellOrderRegular(instrument=instrument,
#                                              order_code=BrokerOrderCodeConstants.INTRADAY,
#                                              order_variety=BrokerOrderVarietyConstants.MARKET,
#                                              quantity=qty)
#         else:
#             raise SystemExit(f'Got invalid sideband_info value: {sideband_info}')
#
#         return self.main_order[instrument]
#
#     def strategy_select_instruments_for_exit(self, candle, instruments_bucket):
#         selected_instruments_bucket = []
#         sideband_info_bucket = []
#
#         for instrument in instruments_bucket:
#             if self.main_order.get(instrument) is not None:
#                 crossover_value = self.get_crossover_value(instrument)
#                 if crossover_value in [1, -1]:
#                     selected_instruments_bucket.append(instrument)
#                     sideband_info_bucket.append({'action': 'EXIT'})
#         return selected_instruments_bucket, sideband_info_bucket
#
#     def strategy_exit_position(self, candle, instrument, sideband_info):
#         if sideband_info['action'] == 'EXIT':
#             self.main_order[instrument].exit_position()
#             self.main_order[instrument] = None
#             return True
#
#         return False

# %% [markdown]
# ### Recipe 2: EMA-Regular-Order Strategy: Backtesting the Strategy

# %%
from datetime import datetime as dt
from pyalgotrading.constants import *

# %%
instruments = algobulls_connection.search_instrument('SBIN')
instruments
# Out:
# [{'id': 7, 'value': 'NSE:SBIN'}]

# %%
instrument = instruments[0]['value']
instrument
# Out:
# 'NSE:SBIN'

# %%
algobulls_connection.backtest(strategy_code=strategy_code1, 
                              start_timestamp=dt(year=2020, month=7, day=1, hour=9, minute=15), 
                              end_timestamp=dt(year=2020, month=7, day=7, hour=15, minute=30), 
                              instrument=instrument, 
                              lots=1,
                              strategy_parameters={
                                  'timeperiod1': 5,
                                  'timeperiod2': 12
                              }, 
                              candle_interval=CandleInterval.MINUTES_15)
# Out:
# Setting Strategy Config... Success.
# Submitting BACKTESTING job... Success.

# %%
algobulls_connection.get_backtesting_job_status(strategy_code1)
# Out:
# {'data': 'STARTING'}

# %%
algobulls_connection.get_backtesting_job_status(strategy_code1)
# Out:
# {'data': 'STARTED'}

# %% [markdown]
# ### There's more...

# %%
algobulls_connection.stop_backtesting_job(strategy_code1)
# Out:
# Stopping BACKTESTING job... Success.

# %%
algobulls_connection.get_backtesting_job_status(strategy_code1)
# Out:
# {'data': 'STOPPING'}

# %%
algobulls_connection.get_backtesting_job_status(strategy_code1)
# Out:
# {'data': 'STOPPED'}

# %% [markdown]
# <img src="images/diagrams/abc-job-status-state-diagram.png" width='50%'>

# %% [markdown]
# ### Recipe 3: EMA-Regular-Order Strategy: Fetching Backtesting Logs in Realtime

# %%
logs = algobulls_connection.get_backtesting_logs(strategy_code1)
print(logs)
# Out:
# [2020-07-30 17:25:18] Logs not available yet. Please retry in sometime.

# %%
logs = algobulls_connection.get_backtesting_logs(strategy_code1)
print(logs)
# Out:
# [2020-07-30 11:56:29] Performing sanity checks on cfg strategy_parameters, setting up broker connection and required data structures...
# [2020-07-30 11:56:29] ABBroker connection has been setup successfully.
# [2020-07-30 11:56:29] Sanity checks on cfg successful.
# [2020-07-30 11:56:29] Setting up broker connection...
# [2020-07-30 11:56:29] Broker connection has been setup successfully.
# [2020-07-30 11:56:29] (NSE_EQ) Funds available in client's ABVirtualBroker account is : Rs. '1000000000.00'
# [2020-07-30 11:56:29]
# ########################################
#  INITIALIZING ALGOBULLS CORE (v3.2.0 SECURE MODE)...
# ########################################
# [2020-07-30 11:56:29] Welcome ALGOBULLS VIRTUAL USER!
# [2020-07-30 11:56:29] Reading strategy...
# [2020-07-30 11:56:29] Entering Backtesting mode. Henceforth, all timestamps will be backtesting timestamps...
# [BT] [2020-07-01 09:15:00] [INFO] [tls] STARTING ALGOBULLS CORE...
# [BT] [2020-07-01 09:15:00] [INFO] [tls]
#
#   #####  #######    #    ######  ####### ### #     #  #####
#  #     #    #      # #   #     #    #     #  ##    # #     #
#  #          #     #   #  #     #    #     #  # #   # #
#   #####     #    #     # ######     #     #  #  #  # #  ####
#        #    #    ####### #   #      #     #  #   # # #     #
#  #     #    #    #     # #    #     #     #  #    ## #     #
#   #####     #    #     # #     #    #    ### #     #  #####
#
#     #    #        #####  ####### ######  #     # #       #        #####
#    # #   #       #     # #     # #     # #     # #       #       #     #
#   #   #  #       #       #     # #     # #     # #       #       #
#  #     # #       #  #### #     # ######  #     # #       #        #####
#  ####### #       #     # #     # #     # #     # #       #             #
#  #     # #       #     # #     # #     # #     # #       #       #     #
#  #     # #######  #####  ####### ######   #####  ####### #######  #####
#
#   #####  ####### ######  #######
#  #     # #     # #     # #
#  #       #     # #     # #
#  #       #     # ######  #####
#  #       #     # #   #   #
#  #     # #     # #    #  #
#   #####  ####### #     # #######
# [BT] [2020-07-01 09:15:00] [INFO] [tls] --------------------Master Cfg Parameters:--------------------
# [BT] [2020-07-01 09:15:00] [INFO] [tls] User: ALGOBULLS VIRTUAL USER
# [BT] [2020-07-01 09:15:00] [INFO] [tls] Broker: ABVIRTUALBROKER
# [BT] [2020-07-01 09:15:00] [INFO] [tls] AUTO_ADD_INSTRUMENTS_BUCKET_FROM_POSITIONS: False
# [BT] [2020-07-01 09:15:00] [INFO] [tls] AUTO_ADD_INSTRUMENTS_BUCKET_FROM_HOLDINGS_TPLUS1: False
# [BT] [2020-07-01 09:15:00] [INFO] [tls] AUTO_ADD_INSTRUMENTS_BUCKET_FROM_HOLDINGS_TPLUS2: False
# [BT] [2020-07-01 09:15:00] [INFO] [tls] RESUME_POSITIONS_ON_START: True
# [BT] [2020-07-01 09:15:00] [INFO] [tls] RESUME_HOLDINGS_TPLUS1_ON_START: True
# [BT] [2020-07-01 09:15:00] [INFO] [tls] RESUME_HOLDINGS_TPLUS2_ON_START: True
# [BT] [2020-07-01 09:15:00] [INFO] [tls] EXIT_INTRADAY_ORDERS_ON_STOP: False
# [BT] [2020-07-01 09:15:00] [INFO] [tls] EXIT_TPLUS1_DELIVERY_ORDERS_ON_STOP: False
# [BT] [2020-07-01 09:15:00] [INFO] [tls] EXIT_TPLUS2_DELIVERY_ORDERS_ON_STOP: False
# [BT] [2020-07-01 09:15:00] [INFO] [tls] --------------------User Cfg Parameters: System Parameters--------------------
# [BT] [2020-07-01 09:15:00] [INFO] [tls] Trading type: BACKTESTING
# [BT] [2020-07-01 09:15:00] [INFO] [tls] User trading start time: 2020-07-01 09:15:00
# [BT] [2020-07-01 09:15:00] [INFO] [tls] User trading end time: 2020-07-07 15:30:00
# [BT] [2020-07-01 09:15:00] [INFO] [tls] --------------------User Cfg Parameters: Funds Parameters--------------------
# [BT] [2020-07-01 09:15:00] [INFO] [tls] Credit Exposure: 1
# [BT] [2020-07-01 09:15:00] [INFO] [tls] Fund Allocator: FundAllocatorLots
# [BT] [2020-07-01 09:15:00] [INFO] [tls] Fund Allocator Parameters: {'NUMBER_OF_LOTS': 1}
# [BT] [2020-07-01 09:15:00] [INFO] [tls] --------------------User Cfg Parameters: Candle Parameters--------------------
# [BT] [2020-07-01 09:15:00] [INFO] [tls] Candle interval (sec): 900
# [BT] [2020-07-01 09:15:00] [INFO] [tls] --------------------User Cfg Parameters: Strategy Parameters--------------------
# [BT] [2020-07-01 09:15:00] [INFO] [tls] Strategy: EMA Regular Order Strategy
# [BT] [2020-07-01 09:15:00] [INFO] [tls] Parameters: {'timeperiod1': 5, 'timeperiod2': 12}
# [BT] [2020-07-01 09:15:00] [INFO] [tls] Strategy Mode: INTRADAY
# [BT] [2020-07-01 09:15:00] [INFO] [tls] Instruments Bucket: instruments_bucket | [NSE_EQ:SBIN]
# [BT] [2020-07-01 09:15:00] [INFO] [tls] --------------------User Cfg Parameters: Risk Management Parameters--------------------
# [BT] [2020-07-01 09:15:00] [INFO] [tls] Target Trigger: 0.1000
# [BT] [2020-07-01 09:15:00] [INFO] [tls] Stoploss Trigger: 0.1000
# [BT] [2020-07-01 09:15:00] [INFO] [tls] Trailing Stoploss Trigger: 0.1000
# [BT] [2020-07-01 09:15:00] [INFO] [tls] Desired profit: 20000.0
# [BT] [2020-07-01 09:15:00] [INFO] [tls] Risk Appetite: 10000.0
# [BT] [2020-07-01 09:15:00] [INFO] [tls] PNL scan frequency (in sec): 30
# [BT] [2020-07-01 09:15:00] [INFO] [tls] --------------------User Cfg Parameters: Other Parameters--------------------
# [BT] [2020-07-01 09:15:00] [INFO] [tls] Allow multiple orders for same script: True
# [BT] [2020-07-01 09:15:00] [INFO] [tls] Allow new order when order for script already running: True
# [BT] [2020-07-01 09:15:00] [INFO] [tls] Instrument max orders count: 100
# [BT] [2020-07-01 09:15:00] [INFO] [tls] Remove Instrument if Order Rejected: False
# [BT] [2020-07-01 09:15:00] [INFO] [tls] ------------------------------------------------------------
# [BT] [2020-07-01 09:15:00] [INFO] [utils] Instrument (NSE_EQ:SBIN) subscribed to historical data successfully
# [BT] [2020-07-01 09:15:00] [INFO] [utils] 1 Instrument(s) (re)subscribed to historical data successfully
# [BT] [2020-07-01 09:15:00] [INFO] [utils] Prefetching historical data for 1 instruments...
# [BT] [2020-07-01 09:15:00] [INFO] [strategy]
# ####################
# Strategy Parameters:
# {'timeperiod1': 5, 'timeperiod2': 12}
# ####################
# [BT] [2020-07-01 09:15:00] [INFO] [utils] 1 Instrument(s) (re)subscribed to historical data successfully
# [BT] [2020-07-01 09:15:00] [INFO] [tls] Opening current intraday positions, if any...
# [BT] [2020-07-01 09:15:00] [INFO] [tls] Not processing holdings as STRATEGY_MODE is INTRADAY
# [BT] [2020-07-01 09:15:00] [INFO] [clock] Waiting for 900.00 seconds until end of current candle (2020-07-01 09:30:00)...
# [BT] [2020-07-01 09:30:00] [INFO] [clock] Waiting for 900.00 seconds until end of current candle (2020-07-01 09:45:00)...
# [BT] [2020-07-01 09:45:00] [INFO] [tls] Entering position for instrument: NSE_EQ:SBIN...
# [BT] [2020-07-01 09:45:00] [CRITICAL] [order] [PLACING NEW ORDER] [2020-07-01 09:45:00] [2333198611b744aeb287300d371c8eb5] [BUY] [NSE:SBIN] [QTY:1] [QTY PENDING: 1] [ENTRY PRICE: 180.25] [PRICE:None] [TRIGGER PRICE:None] [ORDER_TYPE_REGULAR] [ORDER_CODE_INTRADAY] [ORDER_VARIETY_MARKET] [ORDER_POSITION_ENTER]
# [BT] [2020-07-01 09:45:00] [INFO] [positions] Created new Position: Position: [BUY] [NSE:SBIN] [QTY:1] [ORDER_TYPE_REGULAR] [ORDER_CODE_INTRADAY]
# [BT] [2020-07-01 09:45:00] [INFO] [order] [ORDER ID RECEIVED] [ABVirtualBroker] [ID:2333198611b744aeb287300d371c8eb5] [BUY] [NSE_EQ:SBIN] [Order ID: (Order: [2020-07-01 09:45:00] [2333198611b744aeb287300d371c8eb5] [BUY] [NSE:SBIN] [QTY:1] [QTY PENDING: 1] [ENTRY PRICE: 180.25] [PRICE:None] [TRIGGER PRICE:None] [ORDER_TYPE_REGULAR] [ORDER_CODE_INTRADAY] [ORDER_VARIETY_MARKET] [ORDER_POSITION_ENTER])
# Status History: PUT ORDER REQ RECEIVED --> VALIDATION PENDING --> OPEN PENDING --> OPEN --> COMPLETE)]
# [BT] [2020-07-01 09:45:00] [INFO] [order] [NEW ORDER SUCCESS] [2020-07-01 09:45:00] [2333198611b744aeb287300d371c8eb5] [BUY] [NSE:SBIN] [QTY:1] [QTY PENDING: 1] [ENTRY PRICE: 180.25] [PRICE:None] [TRIGGER PRICE:None] [ORDER_TYPE_REGULAR] [ORDER_CODE_INTRADAY] [ORDER_VARIETY_MARKET] [ORDER_POSITION_ENTER] [STATUS:COMPLETE]
# [BT] [2020-07-01 09:45:00] [INFO] [tls] Instrument entered position: NSE_EQ:SBIN. Order placed
# [BT] [2020-07-01 09:45:00] [INFO] [clock] Waiting for 900.00 seconds until end of current candle (2020-07-01 10:00:00)...
# [BT] [2020-07-01 10:00:00] [INFO] [clock] Waiting for 900.00 seconds until end of current candle (2020-07-01 10:15:00)...
# [BT] [2020-07-01 10:15:00] [INFO] [clock] Waiting for 900.00 seconds until end of current candle (2020-07-01 10:30:00)...
# [BT] [2020-07-01 10:30:00] [INFO] [clock] Waiting for 900.00 seconds until end of current candle (2020-07-01 10:45:00)...
# [BT] [2020-07-01 10:45:00] [INFO] [clock] Waiting for 900.00 seconds until end of current candle (2020-07-01 11:00:00)...
# [BT] [2020-07-01 11:00:00] [INFO] [clock] Waiting for 900.00 seconds until end of current candle (2020-07-01 11:15:00)...
# [BT] [2020-07-01 11:15:00] [INFO] [clock] Waiting for 900.00 seconds until end of current candle (2020-07-01 11:30:00)...
# [BT] [2020-07-01 11:30:00] [INFO] [clock] Waiting for 900.00 seconds until end of current candle (2020-07-01 11:45:00)...
# [BT] [2020-07-01 11:45:00] [INFO] [clock] Waiting for 900.00 seconds until end of current candle (2020-07-01 12:00:00)...
# [BT] [2020-07-01 12:00:00] [INFO] [clock] Waiting for 900.00 seconds until end of current candle (2020-07-01 12:15:00)...
# [BT] [2020-07-01 12:15:00] [INFO] [clock] Waiting for 900.00 seconds until end of current candle (2020-07-01 12:30:00)...
# [BT] [2020-07-01 12:30:00] [INFO] [clock] Waiting for 900.00 seconds until end of current candle (2020-07-01 12:45:00)...
# [BT] [2020-07-01 12:45:00] [INFO] [clock] Waiting for 900.00 seconds until end of current candle (2020-07-01 13:00:00)...
# [BT] [2020-07-01 13:00:00] [INFO] [clock] Waiting for 900.00 seconds until end of current candle (2020-07-01 13:15:00)...
# [BT] [2020-07-01 13:15:00] [INFO] [clock] Waiting for 900.00 seconds until end of current candle (2020-07-01 13:30:00)...
# [BT] [2020-07-01 13:30:00] [INFO] [clock] Waiting for 900.00 seconds until end of current candle (2020-07-01 13:45:00)...
# [BT] [2020-07-01 13:45:00] [INFO] [clock] Waiting for 900.00 seconds until end of current candle (2020-07-01 14:00:00)...
# [BT] [2020-07-01 14:00:00] [INFO] [clock] Waiting for 900.00 seconds until end of current candle (2020-07-01 14:15:00)...
# [BT] [2020-07-01 14:15:00] [INFO] [clock] Waiting for 900.00 seconds until end of current candle (2020-07-01 14:30:00)...
# [BT] [2020-07-01 14:30:00] [INFO] [clock] Waiting for 900.00 seconds until end of current candle (2020-07-01 14:45:00)...
# [BT] [2020-07-01 14:45:00] [INFO] [clock] Waiting for 900.00 seconds until end of current candle (2020-07-01 15:00:00)...
# [BT] [2020-07-01 15:00:00] [INFO] [clock] Waiting for 900.00 seconds until end of current candle (2020-07-01 15:15:00)...
# [BT] [2020-07-01 15:15:00] [INFO] [clock] Waiting for 900.00 seconds until end of current candle (2020-07-01 15:30:00)...
# [BT] [2020-07-01 15:30:00] [INFO] [oms] Exiting OPEN POSITION (Order: [2020-07-01 09:45:00] [2333198611b744aeb287300d371c8eb5] [BUY] [NSE:SBIN] [QTY:1] [QTY PENDING: 1] [ENTRY PRICE: 180.25] [PRICE:None] [TRIGGER PRICE:None] [ORDER_TYPE_REGULAR] [ORDER_CODE_INTRADAY] [ORDER_VARIETY_MARKET] [ORDER_POSITION_ENTER])...
# [BT] [2020-07-01 15:30:00] [CRITICAL] [order] [PLACING NEW ORDER] [2020-07-01 15:30:00] [67f39f41885b476295e7e959b0470d49] [SELL] [NSE:SBIN] [QTY:1] [QTY PENDING: 1] [ENTRY PRICE: 184.45] [PRICE:None] [TRIGGER PRICE:None] [ORDER_TYPE_REGULAR] [ORDER_CODE_INTRADAY] [ORDER_VARIETY_MARKET] [ORDER_POSITION_EXIT]
# [BT] [2020-07-01 15:30:00] [INFO] [order] [ORDER ID RECEIVED] [ABVirtualBroker] [ID:67f39f41885b476295e7e959b0470d49] [SELL] [NSE_EQ:SBIN] [Order ID: (Order: [2020-07-01 15:30:00] [67f39f41885b476295e7e959b0470d49] [SELL] [NSE:SBIN] [QTY:1] [QTY PENDING: 0] [ENTRY PRICE: 184.45] [PRICE:None] [TRIGGER PRICE:None] [ORDER_TYPE_REGULAR] [ORDER_CODE_INTRADAY] [ORDER_VARIETY_MARKET] [ORDER_POSITION_EXIT])
# Status History: PUT ORDER REQ RECEIVED --> VALIDATION PENDING --> OPEN PENDING --> OPEN --> COMPLETE)]
# [BT] [2020-07-01 15:30:00] [INFO] [order] [NEW ORDER SUCCESS] [2020-07-01 15:30:00] [67f39f41885b476295e7e959b0470d49] [SELL] [NSE:SBIN] [QTY:1] [QTY PENDING: 0] [ENTRY PRICE: 184.45] [PRICE:None] [TRIGGER PRICE:None] [ORDER_TYPE_REGULAR] [ORDER_CODE_INTRADAY] [ORDER_VARIETY_MARKET] [ORDER_POSITION_EXIT] [STATUS:COMPLETE]
# [BT] [2020-07-02 09:15:00] [INFO] [utils] 1 Instrument(s) (re)subscribed to historical data successfully
# [BT] [2020-07-02 09:15:00] [INFO] [tls] Opening current intraday positions, if any...
# [BT] [2020-07-02 09:15:00] [INFO] [tls] Not processing holdings as STRATEGY_MODE is INTRADAY
# [BT] [2020-07-02 09:15:00] [INFO] [clock] Waiting for 900.00 seconds until end of current candle (2020-07-02 09:30:00)...
# [BT] [2020-07-02 09:30:00] [INFO] [clock] Waiting for 900.00 seconds until end of current candle (2020-07-02 09:45:00)...
# [BT] [2020-07-02 09:45:00] [INFO] [clock] Waiting for 900.00 seconds until end of current candle (2020-07-02 10:00:00)...
# [BT] [2020-07-02 10:00:00] [INFO] [clock] Waiting for 900.00 seconds until end of current candle (2020-07-02 10:15:00)...
# [BT] [2020-07-02 10:15:00] [INFO] [clock] Waiting for 900.00 seconds until end of current candle (2020-07-02 10:30:00)...
# [BT] [2020-07-02 10:30:00] [INFO] [clock] Waiting for 900.00 seconds until end of current candle (2020-07-02 10:45:00)...
# [BT] [2020-07-02 10:45:00] [INFO] [clock] Waiting for 900.00 seconds until end of current candle (2020-07-02 11:00:00)...
# [BT] [2020-07-02 11:00:00] [INFO] [clock] Waiting for 900.00 seconds until end of current candle (2020-07-02 11:15:00)...
# [BT] [2020-07-02 11:15:00] [INFO] [tls] Entering position for instrument: NSE_EQ:SBIN...
# [BT] [2020-07-02 11:15:00] [CRITICAL] [order] [PLACING NEW ORDER] [2020-07-02 11:15:00] [76a0c500fd92458e9afcaf0c02bcda4c] [SELL] [NSE:SBIN] [QTY:1] [QTY PENDING: 1] [ENTRY PRICE: 184.4] [PRICE:None] [TRIGGER PRICE:None] [ORDER_TYPE_REGULAR] [ORDER_CODE_INTRADAY] [ORDER_VARIETY_MARKET] [ORDER_POSITION_ENTER]
# [BT] [2020-07-02 11:15:00] [INFO] [positions] Created new Position: Position: [SELL] [NSE:SBIN] [QTY:-1] [ORDER_TYPE_REGULAR] [ORDER_CODE_INTRADAY]
# [BT] [2020-07
0] [PRICE:None] [TRIGGER PRICE:None] [ORDER_TYPE_REGULAR] [ORDER_CODE_INTRADAY] [ORDER_VARIETY_MARKET] [ORDER_POSITION_EXIT]
# Status History: PUT ORDER REQ RECEIVED --> VALIDATION PENDING --> OPEN PENDING --> OPEN --> COMPLETE
#
#
# POSITIONS:
#
#
# HOLDINGS:

# %% [markdown]
# ### Recipe 4: EMA-Regular-Order Strategy: Fetching Backtesting Reports - Profit-n-Loss Table

# %%
algobulls_connection.get_backtesting_report_pnl_table(strategy_code1, show_all_rows=True)
# Out:
#     instrument      entry_timestamp entry_transaction_type entry_quantity  \
# 0  NSE_EQ:SBIN  2020-07-07 13:15:00                    BUY              1
# 1  NSE_EQ:SBIN  2020-07-06 14:45:00                   SELL              1
# 2  NSE_EQ:SBIN  2020-07-06 09:30:00                    BUY              1
# 3  NSE_EQ:SBIN  2020-07-03 13:15:00                   SELL              1
# 4  NSE_EQ:SBIN  2020-07-03 12:00:00                    BUY              1
# 5  NSE_EQ:SBIN  2020-07-02 15:00:00                   SELL              1
# 6  NSE_EQ:SBIN  2020-07-02 12:00:00                    BUY              1
# 7  NSE_EQ:SBIN  2020-07-02 11:15:00                   SELL              1
# 8  NSE_EQ:SBIN  2020-07-01 09:45:00                    BUY              1
#
#   entry_price       exit_timestamp exit_transaction_type exit_quantity  \
# 0      186.55  2020-07-07 15:30:00                  SELL             1
# 1      187.85  2020-07-06 15:30:00                   BUY             1
# 2      187.65  2020-07-06 14:45:00                  SELL             1
# 3       184.6  2020-07-03 15:30:00                   BUY             1
# 4      185.45  2020-07-03 13:15:00                  SELL             1
# 5       185.6  2020-07-02 15:30:00                   BUY             1
# 6      185.55  2020-07-02 15:00:00                  SELL             1
# 7       184.4  2020-07-02 12:00:00                   BUY             1
# 8      180.25  2020-07-01 15:30:00                  SELL             1
#
#   exit_price pnl_absolute pnl_percentage pnl_cumulative_absolute  \
# 0      188.0         1.45           0.78                    3.75
# 1      187.9        -0.05          -0.03                     2.3
# 2     187.85          0.2           0.11                    2.35
# 3      184.6         -0.0           -0.0                    2.15
# 4      184.6        -0.85          -0.46                    2.15
# 5      185.7         -0.1          -0.05                     3.0
# 6      185.6         0.05           0.03                     3.1
# 7     185.55        -1.15          -0.62                    3.05
# 8     184.45          4.2           2.33                     4.2
#
#   pnl_cumulative_percentage
# 0                      2.09
# 1                      1.31
# 2                      1.34
# 3                      1.23
# 4                      1.23
# 5                      1.69
# 6                      1.74
# 7                      1.71
# 8                      2.33

# %% [markdown]
# ### Recipe 5: EMA-Regular-Order Strategy: Fetching Backtesting Reports - Statistics Table

# %%
algobulls_connection.get_backtesting_report_statistics(strategy_code1)
# Out:
#                    highlight_type highlight_value
# 0                         Net PnL            3.75
# 1                       Net PnL %            2.09
# 2                    Max Drawdown            2.15
# 3                  Max Drawdown %            1.16
# 4                Number of Trades               9
# 5                  Number of Wins               5
# 6                Number of Looses               4
# 7           Number of Long Trades               5
# 8          Number of Short Trades               4
# 9                        Max Gain             4.2
# 10                       Min Gain           -1.15
# 11  Avg. Profit per winning trade            1.48
# 12   Avg. Profit per losing trade           -0.54

# %% [markdown]
# ### Recipe 6: EMA-Regular-Order Strategy: Fetching Backtesting Reports - Order History

# %%
order_history = algobulls_connection.get_backtesting_report_order_history(strategy_code1)
print(order_history)
# Out:
# +-------------+---------------------+----------------------------------+------+
# | INST        | TIME                | ID                               | TT   |
# |-------------+---------------------+----------------------------------+------|
# | NSE_EQ:SBIN | 2020-07-01 09:45:00 | 2333198611b744aeb287300d371c8eb5 | BUY  |
# +-------------+---------------------+----------------------------------+------+
# +----+---------------------+------------------------+-------+
# |    | TIME                | STATE                  | MSG   |
# |----+---------------------+------------------------+-------|
# |  0 | 2020-07-01 09:45:00 | PUT ORDER REQ RECEIVED |       |
# |  1 | 2020-07-01 09:45:00 | VALIDATION PENDING     |       |
# |  2 | 2020-07
15:30:00 | PUT ORDER REQ RECEIVED |       |
# |  1 | 2020-07-07 15:30:00 | VALIDATION PENDING     |       |
# |  2 | 2020-07-07 15:30:00 | OPEN PENDING           |       |
# |  3 | 2020-07-07 15:30:00 | OPEN                   |       |
# |  4 | 2020-07-07 15:30:00 | COMPLETE               |       |
# +----+---------------------+------------------------+-------+

# %% [markdown]
# ### Recipe 7: MACD-Bracket-Order Strategy: Fetching the Strategy

# %%
from pyalgotrading.algobulls import AlgoBullsConnection

# %%
algobulls_connection = AlgoBullsConnection()

# %%
algobulls_connection.get_authorization_url()
# Out:
# Please login to this URL with your AlgoBulls credentials and get your developer access token: https://app.algobulls.com/user/login
# 'https://app.algobulls.com/user/login'

# %%
algobulls_connection.set_access_token('b4e0f923d085d48f4665a079d760d2bb94c33a94')

# %%
all_strategies = algobulls_connection.get_all_strategies()
all_strategies
# Out:
#                        strategyCode                 strategyName
# 0  49287246f9704bbcbad76ade9e2091d9   EMA Regular Order Strategy
# 1  4faf514fe096432b8e9f80f5951bd2ea  MACD Bracket Order Strategy

# %%
strategy_code2 = all_strategies.iloc[1]['strategyCode']
strategy_code2
# Out:
# '4faf514fe096432b8e9f80f5951bd2ea'

# %%
strategy_details2 = algobulls_connection.get_strategy_details(strategy_code2)
print(strategy_details2)
# Out:
# class StrategyMACDBracketOrder(StrategyBase):
#
#     def __init__(self, *args, **kwargs):
#         super().__init__(*args, **kwargs)
#
#         self.fastMA_period = self.strategy_parameters['fastma_period']
#         self.slowMA_period = self.strategy_parameters['slowma_period']
#         self.signal_period = self.strategy_parameters['signal_period']
#         self.stoploss = self.strategy_parameters['stoploss_trigger']
#         self.target = self.strategy_parameters['target_trigger']
#         self.trailing_stoploss = self.strategy_parameters['trailing_stoploss_trigger']
#
#         self.main_order = None
#
#     def initialize(self):
#         self.main_order = {}
#
#     @staticmethod
#     def name():
#         return 'MACD Bracket Order Strategy'
#
#     @staticmethod
#     def versions_supported():
#         return AlgoBullsEngineVersion.VERSION_3_2_0
#
#     def get_crossover_value(self, instrument):
#         hist_data = self.get_historical_data(instrument)
#         macdline, macdsignal, _ = talib.MACD(hist_data['close'],
#                                              fastperiod=self.fastMA_period,
#                                              slowperiod=self.slowMA_period,
#                                              signalperiod=self.signal_period)
#         crossover_value = self.utils.crossover(macdline, macdsignal)
#         return crossover_value
#
#     def strategy_select_instruments_for_entry(self, candle, instruments_bucket):
#
#         selected_instruments_bucket = []
#         sideband_info_bucket = []
#
#         for instrument in instruments_bucket:
#             crossover_value = self.get_crossover_value(instrument)
#             if crossover_value == 1:
#                 selected_instruments_bucket.append(instrument)
#                 sideband_info_bucket.append({'action': 'BUY'})
#             elif crossover_value == -1:
#                 if self.strategy_mode is StrategyMode.INTRADAY:
#                     selected_instruments_bucket.append(instrument)
#                     sideband_info_bucket.append({'action': 'SELL'})
#
#         return selected_instruments_bucket, sideband_info_bucket
#
#     def strategy_enter_position(self, candle, instrument, sideband_info):
#         if sideband_info['action'] == 'BUY':
#             qty = self.number_of_lots * instrument.lot_size
#             ltp = self.broker.get_ltp(instrument)
#             self.main_order[instrument] = \
#                 self.broker.BuyOrderBracket(instrument=instrument,
#                                             order_code=BrokerOrderCodeConstants.INTRADAY,
#                                             order_variety=BrokerOrderVarietyConstants.LIMIT,
#                                             quantity=qty,
#                                             price=ltp,
#                                             stoploss_trigger=ltp - (ltp * self.stoploss),
#                                             target_trigger=ltp + (ltp * self.target),
#                                             trailing_stoploss_trigger=ltp * self.trailing_stoploss)
#
#         elif sideband_info['action'] == 'SELL':
#             qty = self.number_of_lots * instrument.lot_size
#             ltp = self.broker.get_ltp(instrument)
#             self.main_order[instrument] = \
#                 self.broker.SellOrderBracket(instrument=instrument,
#                                              order_code=BrokerOrderCodeConstants.INTRADAY,
#                                              order_variety=BrokerOrderVarietyConstants.LIMIT,
#                                              quantity=qty,
#                                              price=ltp,
#                                              stoploss_trigger=ltp + (ltp * self.stoploss),
#                                              target_trigger=ltp - (ltp * self.target),
#                                              trailing_stoploss_trigger=ltp * self.trailing_stoploss)
#         else:
#             raise SystemExit(f'Got invalid sideband_info value: {sideband_info}')
#
#         return self.main_order[instrument]
#
#     def strategy_select_instruments_for_exit(self, candle, instruments_bucket):
#         selected_instruments_bucket = []
#         sideband_info_bucket = []
#
#         for instrument in instruments_bucket:
#             if self.main_order.get(instrument) is not None:
#                 crossover_value = self.get_crossover_value(instrument)
#                 if crossover_value in [1, -1]:
#                     selected_instruments_bucket.append(instrument)
#                     sideband_info_bucket.append({'action': 'EXIT'})
#         return selected_instruments_bucket, sideband_info_bucket
#
#     def strategy_exit_position(self, candle, instrument, sideband_info):
#         if sideband_info['action'] == 'EXIT':
#             self.main_order[instrument].exit_position()
#             self.main_order[instrument] = None
#             return True
#
#         return False

# %% [markdown]
# ### Recipe 8: MACD-Bracket-Order Strategy: Backtesting the Strategy

# %%
from datetime import datetime as dt
from pyalgotrading.constants import *

# %%
instrument = algobulls_connection.search_instrument('TATASTEEL')
instrument
# Out:
# [{'id': 1, 'value': 'NSE:TATASTEEL'}]

# %%
instrument = instrument[0]['value']
instrument
# Out:
# 'NSE:TATASTEEL'

# %%
algobulls_connection.backtest(strategy_code=strategy_code2, 
                              start_timestamp=dt(year=2020, month=7, day=1, hour=9, minute=15),
                              end_timestamp=dt(year=2020, month=7, day=7, hour=15, minute=30),
                              instrument=instrument,
                              lots=1,
                              strategy_parameters={
                                  'fastma_period': 26, 
                                  'slowma_period': 6, 
                                  'signal_period': 9,
                                  'target_trigger': 0.01, 
                                  'stoploss_trigger': 0.01, 
                                  'trailing_stoploss_trigger': 1
                              },
                              candle_interval=CandleInterval.MINUTES_15)
# Out:
# Setting Strategy Config... Success.
# Submitting BACKTESTING job... Success.

# %%
algobulls_connection.get_backtesting_job_status(strategy_code2)
# Out:
# {'data': 'STARTING'}

# %%
algobulls_connection.get_backtesting_job_status(strategy_code2)
# Out:
# {'data': 'STARTED'}

# %% [markdown]
# ### There's more...

# %%
algobulls_connection.stop_backtesting_job(strategy_code2)
# Out:
# Stopping BACKTESTING job... Success.

# %%
algobulls_connection.get_backtesting_job_status(strategy_code2)
# Out:
# {'data': 'STOPPING'}

# %%
algobulls_connection.get_backtesting_job_status(strategy_code2)
# Out:
# {'data': 'STOPPED'}

# %% [markdown]
# <img src="images/diagrams/abc-job-status-state-diagram.png" width='50%'>

# %% [markdown]
# ### Recipe 9: MACD-Bracket-Order Strategy: Fetching Backtesting Logs in Realtime

# %%
logs = algobulls_connection.get_backtesting_logs(strategy_code2)
print(logs)
# Out:
# [2020-07-30 17:27:25] Logs not available yet. Please retry in sometime.

# %%
logs = algobulls_connection.get_backtesting_logs(strategy_code2)
print(logs)
# Out:
# [2020-07-30 12:00:58] Performing sanity checks on cfg strategy_parameters, setting up broker connection and required data structures...
# [2020-07-30 12:00:58] ABBroker connection has been setup successfully.
# [2020-07-30 12:00:58] Sanity checks on cfg successful.
# [2020-07-30 12:00:58] Setting up broker connection...
# [2020-07-30 12:00:58] Broker connection has been setup successfully.
# [2020-07-30 12:00:58] (NSE_EQ) Funds available in client's ABVirtualBroker account is : Rs. '1000000000.00'
# [2020-07-30 12:00:58]
# ########################################
#  INITIALIZING ALGOBULLS CORE (v3.2.0 SECURE MODE)...
# ########################################
# [2020-07-30 12:00:58] Welcome ALGOBULLS VIRTUAL USER!
# [2020-07-30 12:00:58] Reading strategy...
# [2020-07-30 12:00:58] Entering Backtesting mode. Henceforth, all timestamps will be backtesting timestamps...
# [BT] [2020-07-01 09:15:00] [INFO] [tls] STARTING ALGOBULLS CORE...
# [BT] [2020-07-01 09:15:00] [INFO] [tls]
#
#   #####  #######    #    ######  ####### ### #     #  #####
#  #     #    #      # #   #     #    #     #  ##    # #     #
#  #          #     #   #  #     #    #     #  # #   # #
#   #####     #    #     # ######     #     #  #  #  # #  ####
#        #    #    ####### #   #      #     #  #   # # #     #
#  #     #    #    #     # #    #     #     #  #    ## #     #
#   #####     #    #     # #     #    #    ### #     #  #####
#
#     #    #        #####  ####### ######  #     # #       #        #####
#    # #   #       #     # #     # #     # #     # #       #       #     #
#   #   #  #       #       #     # #     # #     # #       #       #
#  #     # #       #  #### #     # ######  #     # #       #        #####
#  ####### #       #     # #     # #     # #     # #       #             #
#  #     # #       #     # #     # #     # #     # #       #       #     #
#  #     # #######  #####  ####### ######   #####  ####### #######  #####
#
#   #####  ####### ######  #######
#  #     # #     # #     # #
#  #       #     # #     # #
#  #       #     # ######  #####
#  #       #     # #   #   #
#  #     # #     # #    #  #
#   #####  ####### #     # #######
# [BT] [2020-07-01 09:15:00] [INFO] [tls] --------------------Master Cfg Parameters:--------------------
# [BT] [2020-07-01 09:15:00] [INFO] [tls] User: ALGOBULLS VIRTUAL USER
# [BT] [2020-07-01 09:15:00] [INFO] [tls] Broker: ABVIRTUALBROKER
# [BT] [2020-07-01 09:15:00] [INFO] [tls] AUTO_ADD_INSTRUMENTS_BUCKET_FROM_POSITIONS: False
# [BT] [2020-07-01 09:15:00] [INFO] [tls] AUTO_ADD_INSTRUMENTS_BUCKET_FROM_HOLDINGS_TPLUS1: False
# [BT] [2020-07-01 09:15:00] [INFO] [tls] AUTO_ADD_INSTRUMENTS_BUCKET_FROM_HOLDINGS_TPLUS2: False
# [BT] [2020-07-01 09:15:00] [INFO] [tls] RESUME_POSITIONS_ON_START: True
# [BT] [2020-07-01 09:15:00] [INFO] [tls] RESUME_HOLDINGS_TPLUS1_ON_START: True
# [BT] [2020-07-01 09:15:00] [INFO] [tls] RESUME_HOLDINGS_TPLUS2_ON_START: True
# [BT] [2020-07-01 09:15:00] [INFO] [tls] EXIT_INTRADAY_ORDERS_ON_STOP: False
# [BT] [2020-07-01 09:15:00] [INFO] [tls] EXIT_TPLUS1_DELIVERY_ORDERS_ON_STOP: False
# [BT] [2020-07-01 09:15:00] [INFO] [tls] EXIT_TPLUS2_DELIVERY_ORDERS_ON_STOP: False
# [BT] [2020-07-01 09:15:00] [INFO] [tls] --------------------User Cfg Parameters: System Parameters--------------------
# [BT] [2020-07-01 09:15:00] [INFO] [tls] Trading type: BACKTESTING
# [BT] [2020-07-01 09:15:00] [INFO] [tls] User trading start time: 2020-07-01 09:15:00
# [BT] [2020-07-01 09:15:00] [INFO] [tls] User trading end time: 2020-07-07 15:30:00
# [BT] [2020-07-01 09:15:00] [INFO] [tls] --------------------User Cfg Parameters: Funds Parameters--------------------
# [BT] [2020-07-01 09:15:00] [INFO] [tls] Credit Exposure: 1
# [BT] [2020-07-01 09:15:00] [INFO] [tls] Fund Allocator: FundAllocatorLots
# [BT] [2020-07-01 09:15:00] [INFO] [tls] Fund Allocator Parameters: {'NUMBER_OF_LOTS': 1}
# [BT] [2020-07-01 09:15:00] [INFO] [tls] --------------------User Cfg Parameters: Candle Parameters--------------------
# [BT] [2020-07-01 09:15:00] [INFO] [tls] Candle interval (sec): 900
# [BT] [2020-07-01 09:15:00] [INFO] [tls] --------------------User Cfg Parameters: Strategy Parameters--------------------
# [BT] [2020-07-01 09:15:00] [INFO] [tls] Strategy: MACD Bracket Order Strategy
# [BT] [2020-07-01 09:15:00] [INFO] [tls] Parameters: {'fastma_period': 26, 'signal_period': 9, 'slowma_period': 6, 'stoploss_trigger': 0.01, 'target_trigger': 0.01, 'trailing_stoploss_trigger': 1}
# [BT] [2020-07-01 09:15:00] [INFO] [tls] Strategy Mode: INTRADAY
# [BT] [2020-07-01 09:15:00] [INFO] [tls] Instruments Bucket: instruments_bucket | [NSE_EQ:TATASTEEL]
# [BT] [2020-07-01 09:15:00] [INFO] [tls] --------------------User Cfg Parameters: Risk Management Parameters--------------------
# [BT] [2020-07-01 09:15:00] [INFO] [tls] Target Trigger: 0.1000
# [BT] [2020-07-01 09:15:00] [INFO] [tls] Stoploss Trigger: 0.1000
# [BT] [2020-07-01 09:15:00] [INFO] [tls] Trailing Stoploss Trigger: 0.1000
# [BT] [2020-07-01 09:15:00] [INFO] [tls] Desired profit: 20000.0
# [BT] [2020-07-01 09:15:00] [INFO] [tls] Risk Appetite: 10000.0
# [BT] [2020-07-01 09:15:00] [INFO] [tls] PNL scan frequency (in sec): 30
# [BT] [2020-07-01 09:15:00] [INFO] [tls] --------------------User Cfg Parameters: Other Parameters--------------------
# [BT] [2020-07-01 09:15:00] [INFO] [tls] Allow multiple orders for same script: True
# [BT] [2020-07-01 09:15:00] [INFO] [tls] Allow new order when order for script already running: True
# [BT] [2020-07-01 09:15:00] [INFO] [tls] Instrument max orders count: 100
# [BT] [2020-07-01 09:15:00] [INFO] [tls] Remove Instrument if Order Rejected: False
# [BT] [2020-07-01 09:15:00] [INFO] [tls] ------------------------------------------------------------
# [BT] [2020-07-01 09:15:00] [INFO] [utils] Instrument (NSE_EQ:TATASTEEL) subscribed to historical data successfully
# [BT] [2020-07-01 09:15:00] [INFO] [utils] 1 Instrument(s) (re)subscribed to historical data successfully
# [BT] [2020-07-01 09:15:00] [INFO] [utils] Prefetching historical data for 1 instruments...
# [BT] [2020-07-01 09:15:00] [INFO] [strategy]
# ####################
# Strategy Parameters:
# {'fastma_period': 26,
#  'signal_period': 9,
#  'slowma_period': 6,
#  'stoploss_trigger': 0.01,
#  'target_trigger': 0.01,
#  'trailing_stoploss_trigger': 1}
# ####################
# [BT] [2020-07-01 09:15:00] [INFO] [utils] 1 Instrument(s) (re)subscribed to historical data successfully
# [BT] [2020-07-01 09:15:00] [INFO] [tls] Opening current intraday positions, if any...
# [BT] [2020-07-01 09:15:00] [INFO] [tls] Not processing holdings as STRATEGY_MODE is INTRADAY
# [BT] [2020-07-01 09:15:00] [INFO] [clock] Waiting for 900.00 seconds until end of current candle (2020-07-01 09:30:00)...
# [BT] [2020-07-01 09:30:00] [INFO] [clock] Waiting for 900.00 seconds until end of current candle (2020-07-01 09:45:00)...
# [BT] [2020-07-01 09:45:00] [INFO] [clock] Waiting for 900.00 seconds until end of current candle (2020-07-01 10:00:00)...
# [BT] [2020-07-01 10:00:00] [INFO] [clock] Waiting for 900.00 seconds until end of current candle (2020-07-01 10:15:00)...
# [BT] [2020-07-01 10:15:00] [INFO] [clock] Waiting for 900.00 seconds until end of current candle (2020-07-01 10:30:00)...
# [BT] [2020-07-01 10:30:00] [INFO] [clock] Waiting for 900.00 seconds until end of current candle (2020-07-01 10:45:00)...
# [BT] [2020-07-01 10:45:00] [INFO] [clock] Waiting for 900.00 seconds until end of current candle (2020-07-01 11:00:00)...
# [BT] [2020-07-01 11:00:00] [INFO] [clock] Waiting for 900.00 seconds until end of current candle (2020-07-01 11:15:00)...
# [BT] [2020-07-01 11:15:00] [INFO] [clock] Waiting for 900.00 seconds until end of current candle (2020-07-01 11:30:00)...
# [BT] [2020-07-01 11:30:00] [INFO] [clock] Waiting for 900.00 seconds until end of current candle (2020-07-01 11:45:00)...
# [BT] [2020-07-01 11:45:00] [INFO] [clock] Waiting for 900.00 seconds until end of current candle (2020-07-01 12:00:00)...
# [BT] [2020-07-01 12:00:00] [INFO] [clock] Waiting for 900.00 seconds until end of current candle (2020-07-01 12:15:00)...
# [BT] [2020-07-01 12:15:00] [INFO] [clock] Waiting for 900.00 seconds until end of current candle (2020-07-01 12:30:00)...
# [BT] [2020-07-01 12:30:00] [INFO] [tls] Entering position for instrument: NSE_EQ:TATASTEEL...
# [BT] [2020-07-01 12:30:00] [CRITICAL] [order] [PLACING NEW ORDER] [2020-07-01 12:30:00] [1cbefcf395c344c88a228a1b01c32ef6] [BUY] [NSE:TATASTEEL] [QTY:1] [QTY PENDING: 1] [ENTRY PRICE: 322.6] [PRICE:322.6] [TRIGGER PRICE:None] [ORDER_TYPE_BRACKET] [ORDER_CODE_INTRADAY] [ORDER_VARIETY_LIMIT] [ORDER_POSITION_ENTER] [STOPLOSS TRIGGER:319.374] [TARGET TRIGGER:325.826] [TRAILING STOPLOSS TRIGGER:322.6]
# [BT] [2020-07-01 12:30:00] [INFO] [positions] Created new Position: Position: [BUY] [NSE:TATASTEEL] [QTY:1] [ORDER_TYPE_BRACKET] [ORDER_CODE_INTRADAY]
# [BT] [2020-07-01 12:30:00] [INFO] [order] [ORDER ID RECEIVED] [ABVirtualBroker] [ID:1cbefcf395c344c88a228a1b01c32ef6] [BUY] [NSE_EQ:TATASTEEL] [Order ID: (Order: [2020-07-01 12:30:00] [1cbefcf395c344c88a228a1b01c32ef6] [BUY] [NSE:TATASTEEL] [QTY:1] [QTY PENDING: 1] [ENTRY PRICE: 322.6] [PRICE:322.6] [TRIGGER PRICE:None] [ORDER_TYPE_BRACKET] [ORDER_CODE_INTRADAY] [ORDER_VARIETY_LIMIT] [ORDER_POSITION_ENTER] [STOPLOSS TRIGGER:319.374] [TARGET TRIGGER:325.826] [TRAILING STOPLOSS TRIGGER:322.6])
# Status History: PUT ORDER REQ RECEIVED --> VALIDATION PENDING --> OPEN PENDING --> OPEN --> COMPLETE)]
# [BT] [2020-07-01 12:30:00] [INFO] [order] [NEW ORDER SUCCESS] [2020-07-01 12:30:00] [1cbefcf395c344c88a228a1b01c32ef6] [BUY] [NSE:TATASTEEL] [QTY:1] [QTY PENDING: 1] [ENTRY PRICE: 322.6] [PRICE:322.6] [TRIGGER PRICE:None] [ORDER_TYPE_BRACKET] [ORDER_CODE_INTRADAY] [ORDER_VARIETY_LIMIT] [ORDER_POSITION_ENTER] [STOPLOSS TRIGGER:319.374] [TARGET TRIGGER:325.826] [TRAILING STOPLOSS TRIGGER:322.6] [STATUS:COMPLETE]
# [BT] [2020-07-01 12:30:00] [INFO] [tls] Instrument entered position: NSE_EQ:TATASTEEL. Order placed
# [BT] [2020-07-01 12:30:00] [INFO] [clock] Waiting for 900.00 seconds until end of current candle (2020-07-01
09:45:00] [INFO] [clock] Waiting for 900.00 seconds until end of current candle (2020-07-02 10:00:00)...
# [BT] [2020-07-02 10:00:00] [INFO] [clock] Waiting for 900.00 seconds until end of current candle (2020-07-02 10:15:00)...
# [BT] [2020-07-02 10:15:00] [INFO] [clock] Waiting for 900.00 seconds until end of current candle (2020-07-02 10:30:00)...
# [BT] [2020-07-02 10:30:00] [INFO] [clock] Waiting for 900.00 seconds until end of current candle (2020-07-02 10:45:00)...
# [BT] [2020-07-02 10:45:00] [INFO] [clock] Waiting for 900.00 seconds until end of current candle (2020-07-02 11:00:00)...
# [BT] [2020-07-02 11:00:00] [INFO] [clock] Waiting for 900.00 seconds until end of current candle (2020-07-02 11:15:00)...
# [BT] [2020-07-02 11:15:00] [INFO] [clock] Waiting for 900.00 seconds until end of current candle (2020-07-02 11:30:00)...
# [BT] [2020-07-02 11:30:00] [INFO] [clock] Waiting for 900.00 seconds until end of current candle (2020-07-02 11:45:00)...
# [BT] [2020-07-02 11:45:00] [INFO] [clock] Waiting for 900.00 seconds until end of current candle (2020-07-02 12:00:00)...
# [BT] [2020-07-02 12:00:00] [INFO] [clock] Waiting for 900.00 seconds until end of current candle (2020-07-02 12:15:00)...
# [BT] [2020-07-02 12:15:00] [INFO] [clock] Waiting for 900.00 seconds until end of current candle (2020-07-02 12:30:00)...
# [BT] [2020-07-02 12:30:00] [INFO] [clock] Waiting for 900.00 seconds until end of current candle (2020-07-02 12:45:00)...
# [BT] [2020-07-02 12:45:00] [INFO] [clock] Waiting for 900.00 seconds until end of current candle (2020-07-02 13:00:00)...
# [BT] [2020-07-02 13:00:00] [INFO] [clock] Waiting for 900.00 seconds until end of current candle (2020-07-02 13:15:00)...
# [BT] [2020-07-02 13:15:00] [INFO] [clock] Waiting for 900.00 seconds until end of current candle (2020-07-02 13:30:00)...
# [BT] [2020-07-02 13:30:00] [INFO] [clock] Waiting for 900.00 seconds until end of current candle (2020-07-02 13:45:00)...
# [BT] [2020-07-02 13:45:00] [INFO] [clock] Waiting for 900.00 seconds until end of current candle (2020-07-02 14:00:00)...
# [BT] [2020-07-02 14:00:00] [INFO] [clock] Waiting for 900.00 seconds until end of current candle (2020-07-02 14:15:00)...
# [BT] [2020-07-02 14:15:00] [INFO] [clock] Waiting for 900.00 seconds until end of current candle (2020-07-02 14:30:00)...
# [BT] [2020-07-02 14:30:00] [INFO] [clock] Waiting for 900.00 seconds until end of current candle (2020-07-02 14:45:00)...
# [BT] [2020-07-02 14:45:00] [INFO] [clock] Waiting for 900.00 seconds until end of current candle (2020-07-02 15:00:00)...
# [BT] [2020-07-02 15:00:00] [INFO] [clock] Waiting for 900.00 seconds until end of current candle (2020-07-02 15:15:00)...
# [BT] [2020-07-02 15:15:00] [INFO] [clock] Waiting for 900.00 seconds until end of current candle (2020-07-02 15:30:00)...
# [BT] [2020-07-03 09:15:00] [INFO] [utils] 1 Instrument(s) (re)subscribed to historical data successfully
# [BT] [2020-07-03 09:15:00] [INFO] [tls] Opening current intraday positions, if any...
# [BT] [2020-07-03 09:15:00] [INFO] [tls] Not processing holdings as STRATEGY_MODE is INTRADAY
# [BT] [2020-07-03 09:15:00] [INFO] [clock] Waiting for 900.00 seconds until end of current candle (2020-07-03 09:30:00)...
# [BT] [2020-07-03 09:30:00] [INFO] [clock] Waiting for 900.00 seconds until end of current candle (2020-07-03 09:45:00)...
# [BT] [2020-07-03 09:45:00] [INFO] [tls] Entering position for instrument: NSE_EQ:TATASTEEL...
# [BT] [2020-07-03 09:45:00] [CRITICAL] [order] [PLACING NEW ORDER] [2020-07-03 09:45:00] [ea5a4c6c63524f39a53de71f269ee256] [SELL] [NSE:TATASTEEL] [QTY:1] [QTY PENDING: 1] [ENTRY PRICE: 330.8] [PRICE:330.8] [TRIGGER PRICE:None] [ORDER_TYPE_BRACKET] [ORDER_CODE_INTRADAY] [ORDER_VARIETY_LIMIT] [ORDER_POSITION_ENTER] [STOPLOSS TRIGGER:334.108] [TARGET TRIGGER:327.492] [TRAILING STOPLOSS TRIGGER:330.8]
# [BT] [2020-07-03 09:45:00] [INFO] [positions] Created new Position: Position: [SELL] [NSE:TATASTEEL] [QTY:-1] [ORDER_TYPE_BRACKET] [ORDER_CODE_INTRADAY]
# [BT] [2020-07-03 09:45:00] [INFO] [order] [ORDER ID RECEIVED] [ABVirtualBroker] [ID:ea5a4c6c63524f39a53de71f269ee256] [SELL] [NSE_EQ:TATASTEEL] [Order ID: (Order: [2020-07-03 09:45:00] [ea5a4c6c63524f39a53de71f269ee256] [SELL] [NSE:TATASTEEL] [QTY:1] [QTY PENDING: 1] [ENTRY PRICE: 330.8] [PRICE:330.8] [TRIGGER PRICE:None] [ORDER_TYPE_BRACKET] [ORDER_CODE_INTRADAY] [ORDER_VARIETY_LIMIT] [ORDER_POSITION_ENTER] [STOPLOSS TRIGGER:334.108] [TARGET TRIGGER:327.492] [TRAILING STOPLOSS TRIGGER:330.8])
# Status History: PUT ORDER REQ RECEIVED --> VALIDATION PENDING --> OPEN PENDING --> OPEN --> COMPLETE)]
# [BT] [2020-07-03 09:45:00] [INFO] [order] [NEW ORDER SUCCESS] [2020-07-03 09:45:00] [ea5a4c6c63524f39a53de71f269ee256] [SELL] [NSE:TATASTEEL] [QTY:1] [QTY PENDING: 1] [ENTRY PRICE: 330.8] [PRICE:330.8] [TRIGGER PRICE:None] [ORDER_TYPE_BRACKET] [ORDER_CODE_INTRADAY] [ORDER_VARIETY_LIMIT] [ORDER_POSITION_ENTER] [STOPLOSS TRIGGER:334.108] [TARGET TRIGGER:327.492] [TRAILING STOPLOSS TRIGGER:330.8] [STATUS:COMPLETE]
# [BT] [2020-07-03 09:45:00] [INFO] [tls] Instrument entered position: NSE_EQ:TATASTEEL. Order placed
# [BT] [2020-07-03 09:45:00] [INFO] [clock] Waiting for 900.00 seconds until end of current candle (2020-07-03 10:00:00)...
# [BT] [2020-07-03 10:00:00] [CRITICAL] [order] [PLACING NEW ORDER] [2020-07-03 10:00:00] [62458cf47d5f4a12b6c31c490451fdb0] [BUY] [NSE:TATASTEEL] [QTY:1] [QTY PENDING: 1] [ENTRY PRICE: 327.45] [PRICE:327.45] [TRIGGER PRICE:None] [ORDER_TYPE_REGULAR] [ORDER_CODE_INTRADAY] [ORDER_VARIETY_LIMIT] [ORDER_POSITION_EXIT]
# [BT] [2020-07-03 10:00:00] [INFO] [order] [ORDER ID RECEIVED] [ABVirtualBroker] [ID:62458cf47d5f4a12b6c31c490451fdb0] [BUY] [NSE_EQ:TATASTEEL] [Order ID: (Order: [2020-07-03 10:00:00] [62458cf47d5f4a12b6c31c490451fdb0] [BUY] [NSE:TATASTEEL] [QTY:1] [QTY PENDING: 1] [ENTRY PRICE: 327.45] [PRICE:327.45] [TRIGGER PRICE:None] [ORDER_TYPE_REGULAR] [ORDER_CODE_INTRADAY] [ORDER_VARIETY_LIMIT] [ORDER_POSITION_EXIT])
# Status History: PUT ORDER REQ RECEIVED --> VALIDATION PENDING --> OPEN PENDING --> OPEN)]
# [BT] [2020-07-03 10:00:00] [INFO] [order] [NEW ORDER SUCCESS] [2020-07-03 10:00:00] [62458cf47d5f4a12b6c31c490451fdb0] [BUY] [NSE:TATASTEEL] [QTY:1] [QTY PENDING: 1] [ENTRY PRICE: 327.45] [PRICE:327.45] [TRIGGER PRICE:None] [ORDER_TYPE_REGULAR] [ORDER_CODE_INTRADAY] [ORDER_VARIETY_LIMIT] [ORDER_POSITION_EXIT] [STATUS:OPEN]
# [BT] [2020-07-03 10:00:00] [CRITICAL] [order] [PLACING NEW ORDER] [2020-07-03 10:00:00] [03436b72ad8a47a8b29bb727876b0b95] [BUY] [NSE:TATASTEEL] [QTY:1] [QTY PENDING: 1] [ENTRY PRICE: 334.1] [PRICE:334.1] [TRIGGER PRICE:334.1] [ORDER_TYPE_REGULAR] [ORDER_CODE_INTRADAY] [ORDER_VARIETY_STOPLOSS_LIMIT] [ORDER_POSITION_EXIT]
# [BT] [2020-07-03 10:00:00] [INFO] [order] [ORDER ID RECEIVED] [ABVirtualBroker] [ID:03436b72ad8a47a8b29bb727876b0b95] [BUY] [NSE_EQ:TATASTEEL] [Order ID: (Order: [2020-07-03 10:00:00] [03436b72ad8a47a8b29bb727876b0b95] [BUY] [NSE:TATASTEEL] [QTY:1] [QTY PENDING: 1] [ENTRY PRICE: 334.1] [PRICE:334.1] [TRIGGER PRICE:334.1] [ORDER_TYPE_REGULAR] [ORDER_CODE_INTRADAY] [ORDER_VARIETY_STOPLOSS_LIMIT] [ORDER_POSITION_EXIT])
# Status History: PUT ORDER REQ RECEIVED --> VALIDATION PENDING --> OPEN PENDING --> TRIGGER PENDING)]
# [BT] [2020-07-03 10:00:00] [INFO] [order] [NEW ORDER SUCCESS] [2020-07-03 10:00:00] [03436b72ad8a47a8b29bb727876b0b95] [BUY] [NSE:TATASTEEL] [QTY:1] [QTY PENDING: 1] [ENTRY PRICE: 334.1] [PRICE:334.1] [TRIGGER PRICE:334.1] [ORDER_TYPE_REGULAR] [ORDER_CODE_INTRADAY] [ORDER_VARIETY_STOPLOSS_LIMIT] [ORDER_POSITION_EXIT] [STATUS:TRIGGER PENDING]
# [BT] [2020-07-03 10:00:00] [INFO] [clock] Waiting for 900.00 seconds until end of current candle (2020-07-03 10:15:00)...
# [BT] [2020-07-03 10:15:00] [INFO] [clock] Waiting for 900.00 seconds until end of current candle (2020-07-03 10:30:00)...
# [BT] [2020-07-03 10:30:00] [INFO] [clock] Waiting for 900.00 seconds until end of current candle (2020-07-03 10:45:00)...
# [BT] [2020-07-03 10:45:00] [INFO] [clock] Waiting for 900.00 seconds until end of current candle (2020-07-03 11:00:00)...
# [BT] [2020-07-03 11:00:00] [INFO] [clock] Waiting for 900.00 seconds until end of current candle (2020-07-03 11:15:00)...
# [BT] [2020-07-03 11:15:00] [INFO] [clock] Waiting for 900.00 seconds until end of current candle (2020-07-03 11:30:00)...
# [BT] [2020-07-03 11:30:00] [INFO] [clock] Waiting for 900.00 seconds until end of current candle (2020-07-03 11:45:00)...
# [BT] [2020-07-03 11:45:00] [INFO] [clock] Waiting for 900.00 seconds until end of current candle (2020-07-03 12:00:00)...
# [BT] [2020-07-03 12:00:00] [INFO] [clock] Waiting for 900.00 seconds until end of current candle (2020-07-03 12:15:00)...
# [BT] [2020-07-03 12:15:00] [INFO] [clock] Waiting for 900.00 seconds until end of current candle (2020-07-03 12:30:00)...
# [BT] [2020-07-03 12:30:00] [WARNING] [order] [ID:ea5a4c6c63524f39a53de71f269ee256] [SELL] [NSE_EQ:TATASTEEL] Order was exited manually. Not exiting...
# [BT] [2020-07-03 12:30:00] [INFO] [tls] Entering position for instrument: NSE_EQ:TATASTEEL...
# [BT] [2020-07-03 12:30:00] [CRITICAL] [order] [PLACING NEW ORDER] [2020-07-03 12:30:00] [a88484f7888f496e801515ff400f69ea] [BUY] [NSE:TATASTEEL] [QTY:1] [QTY PENDING: 1] [ENTRY PRICE: 334.45] [PRICE:334.45] [TRIGGER PRICE:None] [ORDER_TYPE_BRACKET] [ORDER_CODE_INTRADAY] [ORDER_VARIETY_LIMIT] [ORDER_POSITION_ENTER] [STOPLOSS TRIGGER:331.1055] [TARGET TRIGGER:337.79449999999997] [TRAILING STOPLOSS TRIGGER:334.45]
# [BT] [2020-07-03 12:30:00] [INFO] [positions] Created new Position: Position: [BUY] [NSE:TATASTEEL] [QTY:1] [ORDER_TYPE_BRACKET] [ORDER_CODE_INTRADAY]
# [BT] [2020-07-03 12:30:00] [INFO] [order] [ORDER ID RECEIVED] [ABVirtualBroker] [ID:a88484f7888f496e801515ff400f69ea] [BUY] [NSE_EQ:TATASTEEL] [Order ID: (Order: [2020-07-03 12:30:00] [a88484f7888f496e801515ff400f69ea] [BUY] [NSE:TATASTEEL] [QTY:1] [QTY PENDING: 1] [ENTRY PRICE: 334.45] [PRICE:334.45] [TRIGGER PRICE:None] [ORDER_TYPE_BRACKET] [ORDER_CODE_INTRADAY] [ORDER_VARIETY_LIMIT] [ORDER_POSITION_ENTER] [STOPLOSS TRIGGER:331.1055] [TARGET TRIGGER:337.79449999999997] [TRAILING STOPLOSS TRIGGER:334.45])
# Status History: PUT ORDER REQ RECEIVED --> VALIDATION PENDING --> OPEN PENDING --> OPEN --> COMPLETE)]
# [BT] [2020-07-03 12:30:00] [INFO] [order] [NEW ORDER SUCCESS] [2020-07-03 12:30:00] [a88484f7888f496e801515ff400f69ea] [BUY] [NSE:TATASTEEL] [QTY:1] [QTY PENDING: 1] [ENTRY PRICE: 334.45] [PRICE:334.45] [TRIGGER PRICE:None] [ORDER_TYPE_BRACKET] [ORDER_CODE_INTRADAY] [ORDER_VARIETY_LIMIT] [ORDER_POSITION_ENTER] [STOPLOSS TRIGGER:331.1055] [TARGET TRIGGER:337.79449999999997] [TRAILING STOPLOSS TRIGGER:334.45] [STATUS:COMPLETE]
# [BT] [2020-07-03 12:30:00] [INFO] [tls] Instrument entered position: NSE_EQ:TATASTEEL. Order placed
# [BT] [2020-07-03 12:30:00] [INFO] [clock] Waiting for 900.00 seconds until end of current candle (2020-07-03 12:45:00)...
# [BT] [2020-07-03 12:45:00] [CRITICAL] [order] [PLACING NEW ORDER] [2020-07-03 12:45:00] [f3c96875a80f41acb4c344febbc6cb43] [SELL] [NSE:TATASTEEL] [QTY:1] [QTY PENDING: 1] [ENTRY PRICE: 337.75] [PRICE:337.75] [TRIGGER PRICE:None] [ORDER_TYPE_REGULAR] [ORDER_CODE_INTRADAY] [ORDER_VARIETY_LIMIT] [ORDER_POSITION_EXIT]
# [BT] [2020-07-03 12:45:00] [INFO] [order] [ORDER ID RECEIVED] [ABVirtualBroker] [ID:f3c96875a80f41acb4c344febbc6cb43] [SELL] [NSE_EQ:TATASTEEL] [Order ID: (Order: [2020-07-03 12:45:00] [f3c96875a80f41acb4c344febbc6cb43] [SELL] [NSE:TATASTEEL] [QTY:1] [QTY PENDING: 1] [ENTRY PRICE: 337.75] [PRICE:337.75] [TRIGGER PRICE:None] [ORDER_TYPE_REGULAR] [ORDER_CODE_INTRADAY] [ORDER_VARIETY_LIMIT] [ORDER_POSITION_EXIT])
# Status History: PUT ORDER REQ RECEIVED --> VALIDATION PENDING --> OPEN PENDING --> OPEN)]
# [BT] [2020-07-03 12:45:00] [INFO] [order] [NEW ORDER SUCCESS] [2020-07-03 12:45:00] [f3c96875a80f41acb4c344febbc6cb43] [SELL] [NSE:TATASTEEL] [QTY:1] [QTY PENDING: 1] [ENTRY PRICE: 337.75] [PRICE:337.75] [TRIGGER PRICE:None] [ORDER_TYPE_REGULAR] [ORDER_CODE_INTRADAY] [ORDER_VARIETY_LIMIT] [ORDER_POSITION_EXIT] [STATUS:OPEN]
# [BT] [2020-07-03 12:45:00] [CRITICAL] [order] [PLACING NEW ORDER] [2020-07-03 12:45:00] [9a7b474106e549f084bb94dfe7686588] [SELL] [NSE:TATASTEEL] [QTY:1] [QTY PENDING: 1] [ENTRY PRICE: 331.1] [PRICE:331.1] [TRIGGER PRICE:331.1] [ORDER_TYPE_REGULAR] [ORDER_CODE_INTRADAY] [ORDER_VARIETY_STOPLOSS_LIMIT] [ORDER_POSITION_EXIT]
# [BT] [2020-07-03 12:45:00] [INFO] [order] [ORDER ID RECEIVED] [ABVirtualBroker] [ID:9a7b474106e549f084bb94dfe7686588] [SELL] [NSE_EQ:TATASTEEL] [Order ID: (Order: [2020-07-03 12:45:00] [9a7b474106e549f084bb94dfe7686588] [SELL] [NSE:TATASTEEL] [QTY:1] [QTY PENDING: 1] [ENTRY PRICE: 331.1] [PRICE:331.1] [TRIGGER PRICE:331.1] [ORDER_TYPE_REGULAR] [ORDER_CODE_INTRADAY] [ORDER_VARIETY_STOPLOSS_LIMIT] [ORDER_POSITION_EXIT])
# Status History: PUT ORDER REQ RECEIVED --> VALIDATION PENDING --> OPEN PENDING --> TRIGGER PENDING)]
# [BT] [2020-07-03 12:45:00] [INFO] [order] [NEW ORDER SUCCESS] [2020-07-03 12:45:00] [9a7b474106e549f084bb94dfe7686588] [SELL] [NSE:TATASTEEL] [QTY:1] [QTY PENDING: 1] [ENTRY PRICE: 331.1] [PRICE:331.1] [TRIGGER PRICE:331.1] [ORDER_TYPE_REGULAR] [ORDER_CODE_INTRADAY] [ORDER_VARIETY_STOPLOSS_LIMIT] [ORDER_POSITION_EXIT] [STATUS:TRIGGER PENDING]
# [BT] [2020-07-03 12:45:00] [INFO] [order] Exiting child orders...
# [BT] [2020-07-03 12:45:00] [INFO] [order] Cancelling order... (Order: [2020-07-03 12:45:00] [f3c96875a80f41acb4c344febbc6cb43] [SELL] [NSE:TATASTEEL] [QTY:1] [QTY PENDING: 1] [ENTRY PRICE: 337.75] [PRICE:337.75] [TRIGGER PRICE:None] [ORDER_TYPE_REGULAR] [ORDER_CODE_INTRADAY] [ORDER_VARIETY_LIMIT] [ORDER_POSITION_EXIT])
# Status History: PUT ORDER REQ RECEIVED --> VALIDATION PENDING --> OPEN PENDING --> OPEN)
# [BT] [2020-07-03 12:45:00] [INFO] [order] Cancelling order... (Order: [2020-07-03 12:45:00] [9a7b474106e549f084bb94dfe7686588] [SELL] [NSE:TATASTEEL] [QTY:1] [QTY PENDING: 1] [ENTRY PRICE: 331.1] [PRICE:331.1] [TRIGGER PRICE:331.1] [ORDER_TYPE_REGULAR] [ORDER_CODE_INTRADAY] [ORDER_VARIETY_STOPLOSS_LIMIT] [ORDER_POSITION_EXIT])
# Status History: PUT ORDER REQ RECEIVED --> VALIDATION PENDING --> OPEN PENDING --> TRIGGER PENDING)
# [BT] [2020-07-03 12:45:00] [INFO] [order] Exiting main bracket order...
# [BT] [2020-07-03 12:45:00] [CRITICAL] [order] [PLACING NEW ORDER] [2020-07-03 12:45:00] [1dab5ff3edb046918fe45d43f189341e] [SELL] [NSE:TATASTEEL] [QTY:1] [QTY PENDING: 1] [ENTRY PRICE: 333.5] [PRICE:None] [TRIGGER PRICE:None] [ORDER_TYPE_REGULAR] [ORDER_CODE_INTRADAY] [ORDER_VARIETY_MARKET] [ORDER_POSITION_EXIT]
# [BT] [2020-07-03 12:45:00] [INFO] [order] [ORDER ID RECEIVED] [ABVirtualBroker] [ID:1dab5ff3edb046918fe45d43f189341e] [SELL] [NSE_EQ:TATASTEEL] [Order ID: (Order: [2020-07-03 12:45:00] [1dab5ff3edb046918fe45d43f189341e] [SELL] [NSE:TATASTEEL] [QTY:1] [QTY PENDING: 0] [ENTRY PRICE: 333.5] [PRICE:None] [TRIGGER PRICE:None] [ORDER_TYPE_REGULAR] [ORDER_CODE_INTRADAY] [ORDER_VARIETY_MARKET] [ORDER_POSITION_EXIT])
# Status History: PUT ORDER REQ RECEIVED --> VALIDATION PENDING --> OPEN PENDING --> OPEN --> COMPLETE)]
# [BT] [2020-07-03 12:45:00] [INFO] [order] [NEW ORDER SUCCESS] [2020-07-03 12:45:00] [1dab5ff3edb046918fe45d43f189341e] [SELL] [NSE:TATASTEEL] [QTY:1] [QTY PENDING: 0] [ENTRY PRICE: 333.5] [PRICE:None] [TRIGGER PRICE:None] [ORDER_TYPE_REGULAR] [ORDER_CODE_INTRADAY] [ORDER_VARIETY_MARKET] [ORDER_POSITION_EXIT] [STATUS:COMPLETE]
# [BT] [2020-07-03 12:45:00] [INFO] [tls] Entering position for instrument: NSE_EQ:TATASTEEL...
# [BT] [2020-07-03 12:45:00] [CRITICAL] [order] [PLACING NEW ORDER] [2020-07-03 12:45:00] [32948c0159da4481891bd29daec2ff0a] [SELL] [NSE:TATASTEEL] [QTY:1] [QTY PENDING: 1] [ENTRY PRICE: 333.5] [PRICE:333.5] [TRIGGER PRICE:None] [ORDER_TYPE_BRACKET] [ORDER_CODE_INTRADAY] [ORDER_VARIETY_LIMIT] [ORDER_POSITION_ENTER] [STOPLOSS TRIGGER:336.835] [TARGET TRIGGER:330.165] [TRAILING STOPLOSS TRIGGER:333.5]
# [BT] [2020-07-03 12:45:00] [INFO] [positions] Created new Position: Position: [SELL] [NSE:TATASTEEL] [QTY:-1] [ORDER_TYPE_BRACKET] [ORDER_CODE_INTRADAY]
# [BT] [2020-07-03 12:45:00] [INFO] [order] [ORDER ID RECEIVED] [ABVirtualBroker] [ID:32948c0159da4481891bd29daec2ff0a] [SELL] [NSE_EQ:TATASTEEL] [Order ID: (Order: [2020-07-03 12:45:00] [32948c0159da4481891bd29daec2ff0a] [SELL] [NSE:TATASTEEL] [QTY:1] [QTY PENDING: 1] [ENTRY PRICE: 333.5] [PRICE:333.5] [TRIGGER PRICE:None] [ORDER_TYPE_BRACKET] [ORDER_CODE_INTRADAY] [ORDER_VARIETY_LIMIT] [ORDER_POSITION_ENTER] [STOPLOSS TRIGGER:336.835] [TARGET TRIGGER:330.165] [TRAILING STOPLOSS TRIGGER:333.5])
# Status History: PUT ORDER REQ RECEIVED --> VALIDATION PENDING --> OPEN PENDING --> OPEN --> COMPLETE)]
# [BT] [2020-07-03 12:45:00] [INFO] [order] [NEW ORDER SUCCESS] [2020-07-03 12:45:00] [32948c0159da4481891bd29daec2ff0a] [SELL] [NSE:TATASTEEL] [QTY:1] [QTY PENDING: 1] [ENTRY PRICE: 333.5] [PRICE:333.5] [TRIGGER PRICE:None] [ORDER_TYPE_BRACKET] [ORDER_CODE_INTRADAY] [ORDER_VARIETY_LIMIT] [ORDER_POSITION_ENTER] [STOPLOSS TRIGGER:336.835] [TARGET TRIGGER:330.165] [TRAILING STOPLOSS TRIGGER:333.5] [STATUS:COMPLETE]
# [BT] [2020-07-03 12:45:00] [INFO] [tls] Instrument entered position: NSE_EQ:TATASTEEL. Order placed
# [BT] [2020-07-03 12:45:00] [INFO] [clock] Waiting for 900.00 seconds until end of current candle (2020-07-03 13:00:00)...
# [BT] [2020-07-03 13:00:00] [CRITICAL] [order] [PLACING NEW ORDER] [2020-07-03 13:00:00] [6f1fdd54207f499aae0d71ba41a94891] [BUY] [NSE:TATASTEEL] [QTY:1] [QTY PENDING: 1] [ENTRY PRICE: 330.15] [PRICE:330.15] [TRIGGER PRICE:None] [ORDER_TYPE_REGULAR] [ORDER_CODE_INTRADAY] [ORDER_VARIETY_LIMIT] [ORDER_POSITION_EXIT]
# [BT] [2020-07-03 13:00:00] [INFO] [order] [ORDER ID RECEIVED] [ABVirtualBroker] [ID:6f1fdd54207f499aae0d71ba41a94891] [BUY] [NSE_EQ:TATASTEEL] [Order ID: (Order: [2020-07-03 13:00:00] [6f1fdd54207f499aae0d71ba41a94891] [BUY] [NSE:TATASTEEL] [QTY:1] [QTY PENDING: 1] [ENTRY PRICE: 330.15] [PRICE:330.15] [TRIGGER PRICE:None] [ORDER_TYPE_REGULAR] [ORDER_CODE_INTRADAY] [ORDER_VARIETY_LIMIT] [ORDER_POSITION_EXIT])
# Status History: PUT ORDER REQ RECEIVED --> VALIDATION PENDING --> OPEN PENDING --> OPEN)]
# [BT] [2020-07-03 13:00:00] [INFO] [order] [NEW ORDER SUCCESS] [2020-07-03 13:00:00] [6f1fdd54207f499aae0d71ba41a94891] [BUY] [NSE:TATASTEEL] [QTY:1] [QTY PENDING: 1] [ENTRY PRICE: 330.15] [PRICE:330.15] [TRIGGER PRICE:None] [ORDER_TYPE_REGULAR] [ORDER_CODE_INTRADAY] [ORDER_VARIETY_LIMIT] [ORDER_POSITION_EXIT] [STATUS:OPEN]
# [BT] [2020-07-03 13:00:00] [CRITICAL] [order] [PLACING NEW ORDER] [2020-07-03 13:00:00] [446a3850abf145288dff03854fa20ec3] [BUY] [NSE:TATASTEEL] [QTY:1] [QTY PENDING: 1] [ENTRY PRICE: 336.8] [PRICE:336.8] [TRIGGER PRICE:336.8] [ORDER_TYPE_REGULAR] [ORDER_CODE_INTRADAY] [ORDER_VARIETY_STOPLOSS_LIMIT] [ORDER_POSITION_EXIT]
# [BT] [2020-07-03 13:00:00] [INFO] [order] [ORDER ID RECEIVED] [ABVirtualBroker] [ID:446a3850abf145288dff03854fa20ec3] [BUY] [NSE_EQ:TATASTEEL] [Order ID: (Order: [2020-07-03 13:00:00] [446a3850abf145288dff03854fa20ec3] [BUY] [NSE:TATASTEEL] [QTY:1] [QTY PENDING: 1] [ENTRY PRICE: 336.8] [PRICE:336.8] [TRIGGER PRICE:336.8] [ORDER_TYPE_REGULAR] [ORDER_CODE_INTRADAY] [ORDER_VARIETY_STOPLOSS_LIMIT] [ORDER_POSITION_EXIT])
# Status History: PUT ORDER REQ RECEIVED --> VALIDATION PENDING --> OPEN PENDING --> TRIGGER PENDING)]
# [BT] [2020-07-03 13:00:00] [INFO] [order] [NEW ORDER SUCCESS] [2020-07-03 13:00:00] [446a3850abf145288dff03854fa20ec3] [BUY] [NSE:TATASTEEL] [QTY:1] [QTY PENDING: 1] [ENTRY PRICE: 336.8] [PRICE:336.8] [TRIGGER PRICE:336.8] [ORDER_TYPE_REGULAR] [ORDER_CODE_INTRADAY] [ORDER_VARIETY_STOPLOSS_LIMIT] [ORDER_POSITION_EXIT] [STATUS:TRIGGER PENDING]
# [BT] [2020-07-03 13:00:00] [INFO] [clock] Waiting for 900.00 seconds until end of current candle (2020-07-03 13:15:00)...
# [BT] [2020-07-03 13:15:00] [INFO] [clock] Waiting for 900.00 seconds until end of current candle (2020-07-03 13:30:00)...
# [BT] [2020-07-03 13:30:00] [INFO] [clock] Waiting for 900.00 seconds until end of current candle (2020-07-03 13:45:00)...
# [BT] [2020-07-03 13:45:00] [INFO] [clock] Waiting for 900.00 seconds until end of current candle (2020-07-03 14:00:00)...
# [BT] [2020-07-03 14:00:00] [INFO] [clock] Waiting for 900.00 seconds until end of current candle (2020-07-03 14:15:00)...
# [BT] [2020-07-03 14:15:00] [INFO] [clock] Waiting for 900.00 seconds until end of current candle (2020-07-03 14:30:00)...
# [BT] [2020-07-03 14:30:00] [INFO] [clock] Waiting for 900.00 seconds until end of current candle (2020-07-03 14:45:00)...
# [BT] [2020-07-03 14:45:00] [INFO] [clock] Waiting for 900.00 seconds until end of current candle (2020-07-03 15:00:00)...
# [BT] [2020-07-03 15:00:00] [INFO] [clock] Waiting for 900.00 seconds until end of current candle (2020-07-03 15:15:00)...
# [BT] [2020-07-03 15:15:00] [INFO] [clock] Waiting for 900.00 seconds until end of current candle (2020-07-03 15:30:00)...
# [BT] [2020-07-06 09:15:00] [INFO] [utils] 1 Instrument(s) (re)subscribed to historical data successfully
# [BT] [2020-07-06 09:15:00] [INFO] [tls] Opening current intraday positions, if any...
# [BT] [2020-07-06 09:15:00] [INFO] [tls] Not processing holdings as STRATEGY_MODE is INTRADAY
# [BT] [2020-07-06 09:15:00] [INFO] [clock] Waiting for 900.00 seconds until end of current candle (2020-07-06 09:30:00)...
# [BT] [2020-07-06 09:30:00] [INFO] [clock] Waiting for 900.00 seconds until end of current candle (2020-07-06 09:45:00)...
# [BT] [2020-07-06 09:45:00] [INFO] [tls] Entering position for instrument: NSE_EQ:TATASTEEL...
# [BT] [2020-07-06 09:45:00] [CRITICAL] [order] [PLACING NEW ORDER] [2020-07-06 09:45:00] [0f4ae537fdf643f2901eeb4aa3bc4a0f] [BUY] [NSE:TATASTEEL] [QTY:1] [QTY PENDING: 1] [ENTRY PRICE: 332.35] [PRICE:332.35] [TRIGGER PRICE:None] [ORDER_TYPE_BRACKET] [ORDER_CODE_INTRADAY] [ORDER_VARIETY_LIMIT] [ORDER_POSITION_ENTER] [STOPLOSS TRIGGER:329.0265] [TARGET TRIGGER:335.67350000000005] [TRAILING STOPLOSS TRIGGER:332.35]
# [BT] [2020-07-06 09:45:00] [INFO] [positions] Created new Position: Position: [BUY] [NSE:TATASTEEL] [QTY:1] [ORDER_TYPE_BRACKET] [ORDER_CODE_INTRADAY]
# [BT] [2020-07-06 09:45:00] [INFO] [order] [ORDER ID RECEIVED] [ABVirtualBroker] [ID:0f4ae537fdf643f2901eeb4aa3bc4a0f] [BUY] [NSE_EQ:TATASTEEL] [Order ID: (Order: [2020-07-06 09:45:00] [0f4ae537fdf643f2901eeb4aa3bc4a0f] [BUY] [NSE:TATASTEEL] [QTY:1] [QTY PENDING: 1] [ENTRY PRICE: 332.35] [PRICE:332.35] [TRIGGER PRICE:None] [ORDER_TYPE_BRACKET] [ORDER_CODE_INTRADAY] [ORDER_VARIETY_LIMIT] [ORDER_POSITION_ENTER] [STOPLOSS TRIGGER:329.0265] [TARGET TRIGGER:335.67350000000005] [TRAILING STOPLOSS TRIGGER:332.35])
# Status History: PUT ORDER REQ RECEIVED --> VALIDATION PENDING --> OPEN PENDING --> OPEN --> COMPLETE)]
# [BT] [2020-07-06 09:45:00] [INFO] [order] [NEW ORDER SUCCESS] [2020-07-06 09:45:00] [0f4ae537fdf643f2901eeb4aa3bc4a0f] [BUY] [NSE:TATASTEEL] [QTY:1] [QTY PENDING: 1] [ENTRY PRICE: 332.35] [PRICE:332.35] [TRIGGER PRICE:None] [ORDER_TYPE_BRACKET] [ORDER_CODE_INTRADAY] [ORDER_VARIETY_LIMIT] [ORDER_POSITION_ENTER] [STOPLOSS TRIGGER:329.0265] [TARGET TRIGGER:335.67350000000005] [TRAILING STOPLOSS TRIGGER:332.35] [STATUS:COMPLETE]
# [BT] [2020-07-06 09:45:00] [INFO] [tls] Instrument entered position: NSE_EQ:TATASTEEL. Order placed
# [BT] [2020-07-06 09:45:00] [INFO] [clock] Waiting for 900.00 seconds until end of current candle (2020-07-06 10:00:00)...
# [BT] [2020-07-06 10:00:00] [CRITICAL] [order] [PLACING NEW ORDER] [2020-07-06 10:00:00] [5acd4ba4137243978efd9aec9054c329] [SELL] [NSE:TATASTEEL] [QTY:1] [QTY PENDING: 1] [ENTRY PRICE: 335.65] [PRICE:335.65] [TRIGGER PRICE:None] [ORDER_TYPE_REGULAR] [ORDER_CODE_INTRADAY] [ORDER_VARIETY_LIMIT] [ORDER_POSITION_EXIT]
# [BT] [2020-07-06 10:00:00] [INFO] [order] [ORDER ID RECEIVED] [ABVirtualBroker] [ID:5acd4ba4137243978efd9aec9054c329] [SELL] [NSE_EQ:TATASTEEL] [Order ID: (Order: [2020-07-06 10:00:00] [5acd4ba4137243978efd9aec9054c329] [SELL] [NSE:TATASTEEL] [QTY:1] [QTY PENDING: 1] [ENTRY PRICE: 335.65] [PRICE:335.65] [TRIGGER PRICE:None] [ORDER_TYPE_REGULAR] [ORDER_CODE_INTRADAY] [ORDER_VARIETY_LIMIT] [ORDER_POSITION_EXIT])
# Status History: PUT ORDER REQ RECEIVED --> VALIDATION PENDING --> OPEN PENDING --> OPEN)]
# [BT] [2020-07-06 10:00:00] [INFO] [order] [NEW ORDER SUCCESS] [2020-07-06 10:00:00] [5acd4ba4137243978efd9aec9054c329] [SELL] [NSE:TATASTEEL] [QTY:1] [QTY PENDING: 1] [ENTRY PRICE: 335.65] [PRICE:335.65] [TRIGGER PRICE:None] [ORDER_TYPE_REGULAR] [ORDER_CODE_INTRADAY] [ORDER_VARIETY_LIMIT] [ORDER_POSITION_EXIT] [STATUS:OPEN]
# [BT] [2020-07-06 10:00:00] [CRITICAL] [order] [PLACING NEW ORDER] [2020-07-06 10:00:00] [8e03fe4428954257af26ee042debd62e] [SELL] [NSE:TATASTEEL] [QTY:1] [QTY PENDING: 1] [ENTRY PRICE: 329.0] [PRICE:329.0] [TRIGGER PRICE:329.0] [ORDER_TYPE_REGULAR] [ORDER_CODE_INTRADAY] [ORDER_VARIETY_STOPLOSS_LIMIT] [ORDER_POSITION_EXIT]
# [BT] [2020-07-06 10:00:00] [INFO] [order] [ORDER ID RECEIVED] [ABVirtualBroker] [ID:8e03fe4428954257af26ee042debd62e] [SELL] [NSE_EQ:TATASTEEL] [Order ID: (Order: [2020-07-06 10:00:00] [8e03fe4428954257af26ee042debd62e] [SELL] [NSE:TATASTEEL] [QTY:1] [QTY PENDING: 1] [ENTRY PRICE: 329.0] [PRICE:329.0] [TRIGGER PRICE:329.0] [ORDER_TYPE_REGULAR] [ORDER_CODE_INTRADAY] [ORDER_VARIETY_STOPLOSS_LIMIT] [ORDER_POSITION_EXIT])
# Status History: PUT ORDER REQ RECEIVED --> VALIDATION PENDING --> OPEN PENDING --> TRIGGER PENDING)]
# [BT] [2020-07-06 10:00:00] [INFO] [order] [NEW ORDER SUCCESS] [2020-07-06 10:00:00] [8e03fe4428954257af26ee042debd62e] [SELL] [NSE:TATASTEEL] [QTY:1] [QTY PENDING: 1] [ENTRY PRICE: 329.0] [PRICE:329.0] [TRIGGER PRICE:329.0] [ORDER_TYPE_REGULAR] [ORDER_CODE_INTRADAY] [ORDER_VARIETY_STOPLOSS_LIMIT] [ORDER_POSITION_EXIT] [STATUS:TRIGGER PENDING]
# [BT] [2020-07-06 10:00:00] [INFO] [clock] Waiting for 900.00 seconds until end of current candle (2020-07-06 10:15:00)...
# [BT] [2020-07-06 10:15:00] [INFO] [clock] Waiting for 900.00 seconds until end of current candle (2020-07-06 10:30:00)...
# [BT] [2020-07-06 10:30:00] [INFO] [clock] Waiting for 900.00 seconds until end of current candle (2020-07-06 10:45:00)...
# [BT] [2020-07-06 10:45:00] [INFO] [clock] Waiting for 900.00 seconds until end of current candle (2020-07-06 11:00:00)...
# [BT] [2020-07-06 11:00:00] [INFO] [clock] Waiting for 900.00 seconds until end of current candle (2020-07-06 11:15:00)...
# [BT] [2020-07-06 11:15:00] [INFO] [clock] Waiting for 900.00 seconds until end of current candle (2020-07-06 11:30:00)...
# [BT] [2020-07-06 11:30:00] [INFO] [clock] Waiting for 900.00 seconds until end of current candle (2020-07-06 11:45:00)...
# [BT] [2020-07-06 11:45:00] [INFO] [clock] Waiting for 900.00 seconds until end of current candle (2020-07-06 12:00:00)...
# [BT] [2020-07-06 12:00:00] [INFO] [clock] Waiting for 900.00 seconds until end of current candle (2020-07-06 12:15:00)...
# [BT] [2020-07-06 12:15:00] [INFO] [clock] Waiting for 900.00 seconds until end of current candle (2020-07-06 12:30:00)...
# [BT] [2020-07-06 12:30:00] [INFO] [clock] Waiting for 900.00 seconds until end of current candle (2020-07-06 12:45:00)...
# [BT] [2020-07-06 12:45:00] [INFO] [clock] Waiting for 900.00 seconds until end of current candle (2020-07-06 13:00:00)...
# [BT] [2020-07-06 13:00:00] [INFO] [clock] Waiting for 900.00 seconds until end of current candle (2020-07-06 13:15:00)...
# [BT] [2020-07-06 13:15:00] [INFO] [clock] Waiting for 900.00 seconds until end of current candle (2020-07-06 13:30:00)...
# [BT] [2020-07-06 13:30:00] [WARNING] [order] [ID:0f4ae537fdf643f2901eeb4aa3bc4a0f] [BUY] [NSE_EQ:TATASTEEL] Order was exited manually. Not exiting...
# [BT] [2020-07-06 13:30:00] [INFO] [tls] Entering position for instrument: NSE_EQ:TATASTEEL...
# [BT] [2020-07-06 13:30:00] [CRITICAL] [order] [PLACING NEW ORDER] [2020-07-06 13:30:00] [b0400fc8e77941f8b72ace6bc3d53bca] [SELL] [NSE:TATASTEEL] [QTY:1] [QTY PENDING: 1] [ENTRY PRICE: 339.65] [PRICE:339.65] [TRIGGER PRICE:None] [ORDER_TYPE_BRACKET] [ORDER_CODE_INTRADAY] [ORDER_VARIETY_LIMIT] [ORDER_POSITION_ENTER] [STOPLOSS TRIGGER:343.0465] [TARGET TRIGGER:336.2535] [TRAILING STOPLOSS TRIGGER:339.65]
# [BT] [2020-07-06 13:30:00] [INFO] [positions] Created new Position: Position: [SELL] [NSE:TATASTEEL] [QTY:-1] [ORDER_TYPE_BRACKET] [ORDER_CODE_INTRADAY]
# [BT] [2020-07-06 13:30:00] [INFO] [order] [ORDER ID RECEIVED] [ABVirtualBroker] [ID:b0400fc8e77941f8b72ace6bc3d53bca] [SELL] [NSE_EQ:TATASTEEL] [Order ID: (Order: [2020-07-06 13:30:00] [b0400fc8e77941f8b72ace6bc3d53bca] [SELL] [NSE:TATASTEEL] [QTY:1] [QTY PENDING: 1] [ENTRY PRICE: 339.65] [PRICE:339.65] [TRIGGER PRICE:None] [ORDER_TYPE_BRACKET] [ORDER_CODE_INTRADAY] [ORDER_VARIETY_LIMIT] [ORDER_POSITION_ENTER] [STOPLOSS TRIGGER:343.0465] [TARGET TRIGGER:336.2535] [TRAILING STOPLOSS TRIGGER:339.65])
# Status History: PUT ORDER REQ RECEIVED --> VALIDATION PENDING --> OPEN PENDING --> OPEN --> COMPLETE)]
# [BT] [2020-07-06 13:30:00] [INFO] [order] [NEW ORDER SUCCESS] [2020-07-06 13:30:00] [b0400fc8e77941f8b72ace6bc3d53bca] [SELL] [NSE:TATASTEEL] [QTY:1] [QTY PENDING: 1] [ENTRY PRICE: 339.65] [PRICE:339.65] [TRIGGER PRICE:None] [ORDER_TYPE_BRACKET] [ORDER_CODE_INTRADAY] [ORDER_VARIETY_LIMIT] [ORDER_POSITION_ENTER] [STOPLOSS TRIGGER:343.0465] [TARGET TRIGGER:336.2535] [TRAILING STOPLOSS TRIGGER:339.65] [STATUS:COMPLETE]
# [BT] [2020-07-06 13:30:00] [INFO] [tls] Instrument entered position: NSE_EQ:TATASTEEL. Order placed
# [BT] [2020-07-06 13:30:00] [INFO] [clock] Waiting for 900.00 seconds until end of current candle (2020-07-06 13:45:00)...
# [BT] [2020-07-06 13:45:00] [CRITICAL] [order] [PLACING NEW ORDER] [2020-07-06 13:45:00] [7d8525013a694cdd81be74755037d7c0] [BUY] [NSE:TATASTEEL] [QTY:1] [QTY PENDING: 1] [ENTRY PRICE: 336.25] [PRICE:336.25] [TRIGGER PRICE:None] [ORDER_TYPE_REGULAR] [ORDER_CODE_INTRADAY] [ORDER_VARIETY_LIMIT] [ORDER_POSITION_EXIT]
# [BT] [2020-07-06 13:45:00] [INFO] [order] [ORDER ID RECEIVED] [ABVirtualBroker] [ID:7d8525013a694cdd81be74755037d7c0] [BUY] [NSE_EQ:TATASTEEL] [Order ID: (Order: [2020-07-06 13:45:00] [7d8525013a694cdd81be74755037d7c0] [BUY] [NSE:TATASTEEL] [QTY:1] [QTY PENDING: 1] [ENTRY PRICE: 336.25] [PRICE:336.25] [TRIGGER PRICE:None] [ORDER_TYPE_REGULAR] [ORDER_CODE_INTRADAY] [ORDER_VARIETY_LIMIT] [ORDER_POSITION_EXIT])
# Status History: PUT ORDER REQ RECEIVED --> VALIDATION PENDING --> OPEN PENDING --> OPEN)]
# [BT] [2020-07-06 13:45:00] [INFO] [order] [NEW ORDER SUCCESS] [2020-07-06 13:45:00] [7d8525013a694cdd81be74755037d7c0] [BUY] [NSE:TATASTEEL] [QTY:1] [QTY PENDING: 1] [ENTRY PRICE: 336.25] [PRICE:336.25] [TRIGGER PRICE:None] [ORDER_TYPE_REGULAR] [ORDER_CODE_INTRADAY] [ORDER_VARIETY_LIMIT] [ORDER_POSITION_EXIT] [STATUS:OPEN]
# [BT] [2020-07-06 13:45:00] [CRITICAL] [order] [PLACING NEW ORDER] [2020-07-06 13:45:00] [984310d2323541c8a5d0b5303ab40bad] [BUY] [NSE:TATASTEEL] [QTY:1] [QTY PENDING: 1] [ENTRY PRICE: 343.0] [PRICE:343.0] [TRIGGER PRICE:343.0] [ORDER_TYPE_REGULAR] [ORDER_CODE_INTRADAY] [ORDER_VARIETY_STOPLOSS_LIMIT] [ORDER_POSITION_EXIT]
# [BT] [2020-07-06 13:45:00] [INFO] [order] [ORDER ID RECEIVED] [ABVirtualBroker] [ID:984310d2323541c8a5d0b5303ab40bad] [BUY] [NSE_EQ:TATASTEEL] [Order ID: (Order: [2020-07-06 13:45:00] [984310d2323541c8a5d0b5303ab40bad] [BUY] [NSE:TATASTEEL] [QTY:1] [QTY PENDING: 1] [ENTRY PRICE: 343.0] [PRICE:343.0] [TRIGGER PRICE:343.0] [ORDER_TYPE_REGULAR] [ORDER_CODE_INTRADAY] [ORDER_VARIETY_STOPLOSS_LIMIT] [ORDER_POSITION_EXIT])
# ...
# Status History: PUT ORDER REQ RECEIVED --> VALIDATION PENDING --> OPEN PENDING --> OPEN)]
# [BT] [2020-07-07 15:00:00] [INFO] [order] [NEW ORDER SUCCESS] [2020-07-07 15:00:00] [36a1bd24bcf7461584e5d28038dcb44a] [BUY] [NSE:TATASTEEL] [QTY:1] [QTY PENDING: 1] [ENTRY PRICE: 326.0] [PRICE:326.0] [TRIGGER PRICE:None] [ORDER_TYPE_REGULAR] [ORDER_CODE_INTRADAY] [ORDER_VARIETY_LIMIT] [ORDER_POSITION_EXIT] [STATUS:OPEN]
# [BT] [2020-07-07 15:00:00] [CRITICAL] [order] [PLACING NEW ORDER] [2020-07-07 15:00:00] [5ebd84229f364d92b380c531d2110bd9] [BUY] [NSE:TATASTEEL] [QTY:1] [QTY PENDING: 1] [ENTRY PRICE: 332.55] [PRICE:332.55] [TRIGGER PRICE:332.55] [ORDER_TYPE_REGULAR] [ORDER_CODE_INTRADAY] [ORDER_VARIETY_STOPLOSS_LIMIT] [ORDER_POSITION_EXIT]
# [BT] [2020-07-07 15:00:00] [INFO] [order] [ORDER ID RECEIVED] [ABVirtualBroker] [ID:5ebd84229f364d92b380c531d2110bd9] [BUY] [NSE_EQ:TATASTEEL] [Order ID: (Order: [2020-07-07 15:00:00] [5ebd84229f364d92b380c531d2110bd9] [BUY] [NSE:TATASTEEL] [QTY:1] [QTY PENDING: 1] [ENTRY PRICE: 332.55] [PRICE:332.55] [TRIGGER PRICE:332.55] [ORDER_TYPE_REGULAR] [ORDER_CODE_INTRADAY] [ORDER_VARIETY_STOPLOSS_LIMIT] [ORDER_POSITION_EXIT])
# Status History: PUT ORDER REQ RECEIVED --> VALIDATION PENDING --> OPEN PENDING --> TRIGGER PENDING)]
# [BT] [2020-07-07 15:00:00] [INFO] [order] [NEW ORDER SUCCESS] [2020-07-07 15:00:00] [5ebd84229f364d92b380c531d2110bd9] [BUY] [NSE:TATASTEEL] [QTY:1] [QTY PENDING: 1] [ENTRY PRICE: 332.55] [PRICE:332.55] [TRIGGER PRICE:332.55] [ORDER_TYPE_REGULAR] [ORDER_CODE_INTRADAY] [ORDER_VARIETY_STOPLOSS_LIMIT] [ORDER_POSITION_EXIT] [STATUS:TRIGGER PENDING]
# [BT] [2020-07-07 15:00:00] [INFO] [clock] Waiting for 900.00 seconds until end of current candle (2020-07-07 15:15:00)...
# [BT] [2020-07-07 15:15:00] [INFO] [clock] Waiting for 900.00 seconds until end of current candle (2020-07-07 15:30:00)...
# [BT] [2020-07-07 15:30:00] [INFO] [oms] Exiting OPEN POSITION (Order: [2020-07-07 14:45:00] [b5c5a86c76fb4f7f845ac7d9087501ae] [SELL] [NSE:TATASTEEL] [QTY:1] [QTY PENDING: 1] [ENTRY PRICE: 329.3] [PRICE:329.3] [TRIGGER PRICE:None] [ORDER_TYPE_BRACKET] [ORDER_CODE_INTRADAY] [ORDER_VARIETY_LIMIT] [ORDER_POSITION_ENTER] [STOPLOSS TRIGGER:332.593] [TARGET TRIGGER:326.007] [TRAILING STOPLOSS TRIGGER:329.3])...
# [BT] [2020-07-07 15:30:00] [INFO] [order] Exiting child orders...
# [BT] [2020-07-07 15:30:00] [INFO] [order] Cancelling order... (Order: [2020-07-07 15:00:00] [36a1bd24bcf7461584e5d28038dcb44a] [BUY] [NSE:TATASTEEL] [QTY:1] [QTY PENDING: 1] [ENTRY PRICE: 326.0] [PRICE:326.0] [TRIGGER PRICE:None] [ORDER_TYPE_REGULAR] [ORDER_CODE_INTRADAY] [ORDER_VARIETY_LIMIT] [ORDER_POSITION_EXIT])
# Status History: PUT ORDER REQ RECEIVED --> VALIDATION PENDING --> OPEN PENDING --> OPEN)
# [BT] [2020-07-07 15:30:00] [INFO] [order] Cancelling order... (Order: [2020-07-07 15:00:00] [5ebd84229f364d92b380c531d2110bd9] [BUY] [NSE:TATASTEEL] [QTY:1] [QTY PENDING: 1] [ENTRY PRICE: 332.55] [PRICE:332.55] [TRIGGER PRICE:332.55] [ORDER_TYPE_REGULAR] [ORDER_CODE_INTRADAY] [ORDER_VARIETY_STOPLOSS_LIMIT] [ORDER_POSITION_EXIT])
# Status History: PUT ORDER REQ RECEIVED --> VALIDATION PENDING --> OPEN PENDING --> TRIGGER PENDING)
# [BT] [2020-07-07 15:30:00] [INFO] [order] Exiting main bracket order...
# [BT] [2020-07-07 15:30:00] [CRITICAL] [order] [PLACING NEW ORDER] [2020-07-07 15:30:00] [a614b94300cd4d8f8dbbebfca00a8065] [BUY] [NSE:TATASTEEL] [QTY:1] [QTY PENDING: 1] [ENTRY PRICE: 331.0] [PRICE:None] [TRIGGER PRICE:None] [ORDER_TYPE_REGULAR] [ORDER_CODE_INTRADAY] [ORDER_VARIETY_MARKET] [ORDER_POSITION_EXIT]
# [BT] [2020-07-07 15:30:00] [INFO] [order] [ORDER ID RECEIVED] [ABVirtualBroker] [ID:a614b94300cd4d8f8dbbebfca00a8065] [BUY] [NSE_EQ:TATASTEEL] [Order ID: (Order: [2020-07-07 15:30:00] [a614b94300cd4d8f8dbbebfca00a8065] [BUY] [NSE:TATASTEEL] [QTY:1] [QTY PENDING: 0] [ENTRY PRICE: 331.0] [PRICE:None] [TRIGGER PRICE:None] [ORDER_TYPE_REGULAR] [ORDER_CODE_INTRADAY] [ORDER_VARIETY_MARKET] [ORDER_POSITION_EXIT])
# Status History: PUT ORDER REQ RECEIVED --> VALIDATION PENDING --> OPEN PENDING --> OPEN --> COMPLETE)]
# [BT] [2020-07-07 15:30:00] [INFO] [order] [NEW ORDER SUCCESS] [2020-07-07 15:30:00] [a614b94300cd4d8f8dbbebfca00a8065] [BUY] [NSE:TATASTEEL] [QTY:1] [QTY PENDING: 0] [ENTRY PRICE: 331.0] [PRICE:None] [TRIGGER PRICE:None] [ORDER_TYPE_REGULAR] [ORDER_CODE_INTRADAY] [ORDER_VARIETY_MARKET] [ORDER_POSITION_EXIT] [STATUS:COMPLETE]
# [BT] [2020-07-07 15:30:00] [INFO] [clock] Candle generation has been stopped...
# [BT] [2020-07-07 15:30:00] [INFO] [tls] Received event END OF MARKET. Stopping Trading Core Engine...
# [BT] [2020-07-07 15:30:00] [CRITICAL] [tls] [User: ALGOBULLS VIRTUAL USER] Trading session completed
# [BT] [2020-07-07 15:30:00] [INFO] [oms]
#
# PENDING ORDERS:
#
#
# COMPLETED ORDERS:
# [2020-07-01 12:30:00] [1cbefcf395c344c88a228a1b01c32ef6] [BUY] [NSE:TATASTEEL] [QTY:1] [QTY PENDING: 0] [ENTRY PRICE: 322.6] [PRICE:322.6] [TRIGGER PRICE:None] [ORDER_TYPE_BRACKET] [ORDER_CODE_INTRADAY] [ORDER_VARIETY_LIMIT] [ORDER_POSITION_ENTER] [STOPLOSS TRIGGER:319.374] [TARGET TRIGGER:325.826] [TRAILING STOPLOSS TRIGGER:322.6]
# Status History: PUT ORDER REQ RECEIVED --> VALIDATION PENDING --> OPEN PENDING --> OPEN --> COMPLETE
#
# [2020-07-01 12:45:00] [fb8be91cdc8e4d4f9c5f5ab9f7bf8934] [SELL] [NSE:TATASTEEL] [QTY:1] [QTY PENDING: 1] [ENTRY PRICE: 325.8] [PRICE:325.8] [TRIGGER PRICE:None] [ORDER_TYPE_REGULAR] [ORDER_CODE_INTRADAY] [ORDER_VARIETY_LIMIT] [ORDER_POSITION_EXIT]
# Status History: PUT ORDER REQ RECEIVED --> VALIDATION PENDING --> OPEN PENDING --> OPEN --> CANCEL PENDING --> CANCELLED
#
# [2020-07-01 12:45:00] [972ffb502d1a4242ae9c1f5d16bdfc46] [SELL] [NSE:TATASTEEL] [QTY:1] [QTY PENDING: 1] [ENTRY PRICE: 319.35] [PRICE:319.35] [TRIGGER PRICE:319.35] [ORDER_TYPE_REGULAR] [ORDER_CODE_INTRADAY] [ORDER_VARIETY_STOPLOSS_LIMIT] [ORDER_POSITION_EXIT]
# Status History: PUT ORDER REQ RECEIVED --> VALIDATION PENDING --> OPEN PENDING --> TRIGGER PENDING --> CANCEL PENDING --> CANCELLED
#
# [2020-07-01 15:30:00] [c0d024b6a3be41f6a22efc826a8729aa] [SELL] [NSE:TATASTEEL] [QTY:1] [QTY PENDING: 0] [ENTRY PRICE: 324.1] [PRICE:None] [TRIGGER PRICE:None] [ORDER_TYPE_REGULAR] [ORDER_CODE_INTRADAY] [ORDER_VARIETY_MARKET] [ORDER_POSITION_EXIT]
# Status History: PUT ORDER REQ RECEIVED --> VALIDATION PENDING --> OPEN PENDING --> OPEN --> COMPLETE
#
# [2020-07-03 09:45:00] [ea5a4c6c63524f39a53de71f269ee256] [SELL] [NSE:TATASTEEL] [QTY:1] [QTY PENDING: 0] [ENTRY PRICE: 330.8] [PRICE:330.8] [TRIGGER PRICE:None] [ORDER_TYPE_BRACKET] [ORDER_CODE_INTRADAY] [ORDER_VARIETY_LIMIT] [ORDER_POSITION_ENTER] [STOPLOSS TRIGGER:334.108] [TARGET TRIGGER:327.492] [TRAILING STOPLOSS TRIGGER:330.8]
# Status History: PUT ORDER REQ RECEIVED --> VALIDATION PENDING --> OPEN PENDING --> OPEN --> COMPLETE
#
# [2020-07-03 10:00:00] [03436b72ad8a47a8b29bb727876b0b95] [BUY] [NSE:TATASTEEL] [QTY:1] [QTY PENDING: 0] [ENTRY PRICE: 334.1] [PRICE:334.1] [TRIGGER PRICE:334.1] [ORDER_TYPE_REGULAR] [ORDER_CODE_INTRADAY] [ORDER_VARIETY_STOPLOSS_LIMIT] [ORDER_POSITION_EXIT]
# Status History: PUT ORDER REQ RECEIVED --> VALIDATION PENDING --> OPEN PENDING --> TRIGGER PENDING --> OPEN --> COMPLETE
#
# [2020-07-03 10:00:00] [62458cf47d5f4a12b6c31c490451fdb0] [BUY] [NSE:TATASTEEL] [QTY:1] [QTY PENDING: 1] [ENTRY PRICE: 327.45] [PRICE:327.45] [TRIGGER PRICE:None] [ORDER_TYPE_REGULAR] [ORDER_CODE_INTRADAY] [ORDER_VARIETY_LIMIT] [ORDER_POSITION_EXIT]
# Status History: PUT ORDER REQ RECEIVED --> VALIDATION PENDING --> OPEN PENDING --> OPEN --> CANCEL PENDING --> CANCELLED
#
# [2020-07-03 12:30:00] [a88484f7888f496e801515ff400f69ea] [BUY] [NSE:TATASTEEL] [QTY:1] [QTY PENDING: 0] [ENTRY PRICE: 334.45] [PRICE:334.45] [TRIGGER PRICE:None] [ORDER_TYPE_BRACKET] [ORDER_CODE_INTRADAY] [ORDER_VARIETY_LIMIT] [ORDER_POSITION_ENTER] [STOPLOSS TRIGGER:331.1055] [TARGET TRIGGER:337.79449999999997] [TRAILING STOPLOSS TRIGGER:334.45]
# Status History: PUT ORDER REQ RECEIVED --> VALIDATION PENDING --> OPEN PENDING --> OPEN --> COMPLETE
#
# [2020-07-03 12:45:00] [f3c96875a80f41acb4c344febbc6cb43] [SELL] [NSE:TATASTEEL] [QTY:1] [QTY PENDING: 1] [ENTRY PRICE: 337.75] [PRICE:337.75] [TRIGGER PRICE:None] [ORDER_TYPE_REGULAR] [ORDER_CODE_INTRADAY] [ORDER_VARIETY_LIMIT] [ORDER_POSITION_EXIT]
# Status History: PUT ORDER REQ RECEIVED --> VALIDATION PENDING --> OPEN PENDING --> OPEN --> CANCEL PENDING --> CANCELLED
#
# [2020-07-03 12:45:00] [9a7b474106e549f084bb94dfe7686588] [SELL] [NSE:TATASTEEL] [QTY:1] [QTY PENDING: 1] [ENTRY PRICE: 331.1] [PRICE:331.1] [TRIGGER PRICE:331.1] [ORDER_TYPE_REGULAR] [ORDER_CODE_INTRADAY] [ORDER_VARIETY_STOPLOSS_LIMIT] [ORDER_POSITION_EXIT]
# Status History: PUT ORDER REQ RECEIVED --> VALIDATION PENDING --> OPEN PENDING --> TRIGGER PENDING --> CANCEL PENDING --> CANCELLED
#
# [2020-07-03 12:45:00] [1dab5ff3edb046918fe45d43f189341e] [SELL] [NSE:TATASTEEL] [QTY:1] [QTY PENDING: 0] [ENTRY PRICE: 333.5] [PRICE:None] [TRIGGER PRICE:None] [ORDER_TYPE_REGULAR] [ORDER_CODE_INTRADAY] [ORDER_VARIETY_MARKET] [ORDER_POSITION_EXIT]
# Status History: PUT ORDER REQ RECEIVED --> VALIDATION PENDING --> OPEN PENDING --> OPEN --> COMPLETE
#
# [2020-07-03 12:45:00] [32948c0159da4481891bd29daec2ff0a] [SELL] [NSE:TATASTEEL] [QTY:1] [QTY PENDING: 0] [ENTRY PRICE: 333.5] [PRICE:333.5] [TRIGGER PRICE:None] [ORDER_TYPE_BRACKET] [ORDER_CODE_INTRADAY] [ORDER_VARIETY_LIMIT] [ORDER_POSITION_ENTER] [STOPLOSS TRIGGER:336.835] [TARGET TRIGGER:330.165] [TRAILING STOPLOSS TRIGGER:333.5]
# Status History: PUT ORDER REQ RECEIVED --> VALIDATION PENDING --> OPEN PENDING --> OPEN --> COMPLETE
#
# [2020-07-03 13:00:00] [6f1fdd54207f499aae0d71ba41a94891] [BUY] [NSE:TATASTEEL] [QTY:1] [QTY PENDING: 0] [ENTRY PRICE: 330.15] [PRICE:330.15] [TRIGGER PRICE:None] [ORDER_TYPE_REGULAR] [ORDER_CODE_INTRADAY] [ORDER_VARIETY_LIMIT] [ORDER_POSITION_EXIT]
# Status History: PUT ORDER REQ RECEIVED --> VALIDATION PENDING --> OPEN PENDING --> OPEN --> COMPLETE
#
# [2020-07-03 13:00:00] [446a3850abf145288dff03854fa20ec3] [BUY] [NSE:TATASTEEL] [QTY:1] [QTY PENDING: 1] [ENTRY PRICE: 336.8] [PRICE:336.8] [TRIGGER PRICE:336.8] [ORDER_TYPE_REGULAR] [ORDER_CODE_INTRADAY] [ORDER_VARIETY_STOPLOSS_LIMIT] [ORDER_POSITION_EXIT]
# Status History: PUT ORDER REQ RECEIVED --> VALIDATION PENDING --> OPEN PENDING --> TRIGGER PENDING --> CANCEL PENDING --> CANCELLED
#
# [2020-07-06 09:45:00] [0f4ae537fdf643f2901eeb4aa3bc4a0f] [BUY] [NSE:TATASTEEL] [QTY:1] [QTY PENDING: 0] [ENTRY PRICE: 332.35] [PRICE:332.35] [TRIGGER PRICE:None] [ORDER_TYPE_BRACKET] [ORDER_CODE_INTRADAY] [ORDER_VARIETY_LIMIT] [ORDER_POSITION_ENTER] [STOPLOSS TRIGGER:329.0265] [TARGET TRIGGER:335.67350000000005] [TRAILING STOPLOSS TRIGGER:332.35]
# Status History: PUT ORDER REQ RECEIVED --> VALIDATION PENDING --> OPEN PENDING --> OPEN --> COMPLETE
#
# [2020-07-06 10:00:00] [5acd4ba4137243978efd9aec9054c329] [SELL] [NSE:TATASTEEL] [QTY:1] [QTY PENDING: 0] [ENTRY PRICE: 335.65] [PRICE:335.65] [TRIGGER PRICE:None] [ORDER_TYPE_REGULAR] [ORDER_CODE_INTRADAY] [ORDER_VARIETY_LIMIT] [ORDER_POSITION_EXIT]
# Status History: PUT ORDER REQ RECEIVED --> VALIDATION PENDING --> OPEN PENDING --> OPEN --> COMPLETE
#
# [2020-07-06 10:00:00] [8e03fe4428954257af26ee042debd62e] [SELL] [NSE:TATASTEEL] [QTY:1] [QTY PENDING: 1] [ENTRY PRICE: 329.0] [PRICE:329.0] [TRIGGER PRICE:329.0] [ORDER_TYPE_REGULAR] [ORDER_CODE_INTRADAY] [ORDER_VARIETY_STOPLOSS_LIMIT] [ORDER_POSITION_EXIT]
# Status History: PUT ORDER REQ RECEIVED --> VALIDATION PENDING --> OPEN PENDING --> TRIGGER PENDING --> CANCEL PENDING --> CANCELLED
#
# [2020-07-06 13:30:00] [b0400fc8e77941f8b72ace6bc3d53bca] [SELL] [NSE:TATASTEEL] [QTY:1] [QTY PENDING: 0] [ENTRY PRICE: 339.65] [PRICE:339.65] [TRIGGER PRICE:None] [ORDER_TYPE_BRACKET] [ORDER_CODE_INTRADAY] [ORDER_VARIETY_LIMIT] [ORDER_POSITION_ENTER] [STOPLOSS TRIGGER:343.0465] [TARGET TRIGGER:336.2535] [TRAILING STOPLOSS TRIGGER:339.65]
# Status History: PUT ORDER REQ RECEIVED --> VALIDATION PENDING --> OPEN PENDING --> OPEN --> COMPLETE
#
# [2020-07-06 13:45:00] [7d8525013a694cdd81be74755037d7c0] [BUY] [NSE:TATASTEEL] [QTY:1] [QTY PENDING: 1] [ENTRY PRICE: 336.25] [PRICE:336.25] [TRIGGER PRICE:None] [ORDER_TYPE_REGULAR] [ORDER_CODE_INTRADAY] [ORDER_VARIETY_LIMIT] [ORDER_POSITION_EXIT]
# Status History: PUT ORDER REQ RECEIVED --> VALIDATION PENDING --> OPEN PENDING --> OPEN --> CANCEL PENDING --> CANCELLED
#
# [2020-07-06 13:45:00] [984310d2323541c8a5d0b5303ab40bad] [BUY] [NSE:TATASTEEL] [QTY:1] [QTY PENDING: 1] [ENTRY PRICE: 343.0] [PRICE:343.0] [TRIGGER PRICE:343.0] [ORDER_TYPE_REGULAR] [ORDER_CODE_INTRADAY] [ORDER_VARIETY_STOPLOSS_LIMIT] [ORDER_POSITION_EXIT]
# Status History: PUT ORDER REQ RECEIVED --> VALIDATION PENDING --> OPEN PENDING --> TRIGGER PENDING --> CANCEL PENDING --> CANCELLED
#
# [2020-07-06 15:30:00] [f1c18daa21904a4abe92dc4d56574719] [BUY] [NSE:TATASTEEL] [QTY:1] [QTY PENDING: 0] [ENTRY PRICE: 338.85] [PRICE:None] [TRIGGER PRICE:None] [ORDER_TYPE_REGULAR] [ORDER_CODE_INTRADAY] [ORDER_VARIETY_MARKET] [ORDER_POSITION_EXIT]
# Status History: PUT ORDER REQ RECEIVED --> VALIDATION PENDING --> OPEN PENDING --> OPEN --> COMPLETE
#
# [2020-07-07 13:15:00] [311caaf7d5564030be54069c0998a7e4] [BUY] [NSE:TATASTEEL] [QTY:1] [QTY PENDING: 0] [ENTRY PRICE: 332.6] [PRICE:332.6] [TRIGGER PRICE:None] [ORDER_TYPE_BRACKET] [ORDER_CODE_INTRADAY] [ORDER_VARIETY_LIMIT] [ORDER_POSITION_ENTER] [STOPLOSS TRIGGER:329.274] [TARGET TRIGGER:335.92600000000004] [TRAILING STOPLOSS TRIGGER:332.6]
# Status History: PUT ORDER REQ RECEIVED --> VALIDATION PENDING --> OPEN PENDING --> OPEN --> COMPLETE
#
# [2020-07-07 13:30:00] [e228d5c2165048eebc28db14e428c200] [SELL] [NSE:TATASTEEL] [QTY:1] [QTY PENDING: 0] [ENTRY PRICE: 329.25] [PRICE:329.25] [TRIGGER PRICE:329.25] [ORDER_TYPE_REGULAR] [ORDER_CODE_INTRADAY] [ORDER_VARIETY_STOPLOSS_LIMIT] [ORDER_POSITION_EXIT]
# Status History: PUT ORDER REQ RECEIVED --> VALIDATION PENDING --> OPEN PENDING --> TRIGGER PENDING --> OPEN --> COMPLETE
#
# [2020-07-07 13:30:00] [1d2d37f3a4004907a44948eb74bf5e6d] [SELL] [NSE:TATASTEEL] [QTY:1] [QTY PENDING: 1] [ENTRY PRICE: 335.9] [PRICE:335.9] [TRIGGER PRICE:None] [ORDER_TYPE_REGULAR] [ORDER_CODE_INTRADAY] [ORDER_VARIETY_LIMIT] [ORDER_POSITION_EXIT]
# Status History: PUT ORDER REQ RECEIVED --> VALIDATION PENDING --> OPEN PENDING --> OPEN --> CANCEL PENDING --> CANCELLED
#
# [2020-07-07 14:45:00] [b5c5a86c76fb4f7f845ac7d9087501ae] [SELL] [NSE:TATASTEEL] [QTY:1] [QTY PENDING: 0] [ENTRY PRICE: 329.3] [PRICE:329.3] [TRIGGER PRICE:None] [ORDER_TYPE_BRACKET] [ORDER_CODE_INTRADAY] [ORDER_VARIETY_LIMIT] [ORDER_POSITION_ENTER] [STOPLOSS TRIGGER:332.593] [TARGET TRIGGER:326.007] [TRAILING STOPLOSS TRIGGER:329.3]
# Status History: PUT ORDER REQ RECEIVED --> VALIDATION PENDING --> OPEN PENDING --> OPEN --> COMPLETE
#
# [2020-07-07 15:00:00] [36a1bd24bcf7461584e5d28038dcb44a] [BUY] [NSE:TATASTEEL] [QTY:1] [QTY PENDING: 1] [ENTRY PRICE: 326.0] [PRICE:326.0] [TRIGGER PRICE:None] [ORDER_TYPE_REGULAR] [ORDER_CODE_INTRADAY] [ORDER_VARIETY_LIMIT] [ORDER_POSITION_EXIT]
# Status History: PUT ORDER REQ RECEIVED --> VALIDATION PENDING --> OPEN PENDING --> OPEN --> CANCEL PENDING --> CANCELLED
#
# [2020-07-07 15:00:00] [5ebd84229f364d92b380c531d2110bd9] [BUY] [NSE:TATASTEEL] [QTY:1] [QTY PENDING: 1] [ENTRY PRICE: 332.55] [PRICE:332.55] [TRIGGER PRICE:332.55] [ORDER_TYPE_REGULAR] [ORDER_CODE_INTRADAY] [ORDER_VARIETY_STOPLOSS_LIMIT] [ORDER_POSITION_EXIT]
# Status History: PUT ORDER REQ RECEIVED --> VALIDATION PENDING --> OPEN PENDING --> TRIGGER PENDING --> CANCEL PENDING --> CANCELLED
#
# [2020-07-07 15:30:00] [a614b94300cd4d8f8dbbebfca00a8065] [BUY] [NSE:TATASTEEL] [QTY:1] [QTY PENDING: 0] [ENTRY PRICE: 331.0] [PRICE:None] [TRIGGER PRICE:None] [ORDER_TYPE_REGULAR] [ORDER_CODE_INTRADAY] [ORDER_VARIETY_MARKET] [ORDER_POSITION_EXIT]
# Status History: PUT ORDER REQ RECEIVED --> VALIDATION PENDING --> OPEN PENDING --> OPEN --> COMPLETE
#
#
# POSITIONS:
#
#
# HOLDINGS:

# %% [markdown]
# ### Recipe 10: MACD-Bracket-Order Strategy: Fetching Backtesting Reports - Profit-n-Loss Table

# %%
algobulls_connection.get_backtesting_report_pnl_table(strategy_code2)
# Out:
#          instrument      entry_timestamp entry_transaction_type  \
# 0  NSE_EQ:TATASTEEL  2020-07-07 14:45:00                   SELL
# 1  NSE_EQ:TATASTEEL  2020-07-07 13:15:00                    BUY
# 2  NSE_EQ:TATASTEEL  2020-07-06 13:30:00                   SELL
# 3  NSE_EQ:TATASTEEL  2020-07-06 09:45:00                    BUY
# 4  NSE_EQ:TATASTEEL  2020-07-03 12:45:00                   SELL
# 5  NSE_EQ:TATASTEEL  2020-07-03 12:30:00                    BUY
# 6  NSE_EQ:TATASTEEL  2020-07-03 09:45:00                   SELL
# 7  NSE_EQ:TATASTEEL  2020-07-01 12:30:00                    BUY
#
#   entry_quantity entry_price       exit_timestamp exit_transaction_type  \
# 0              1       329.3  2020-07-07 15:30:00                   BUY
# 1              1       332.6  2020-07-07 13:30:00                  SELL
# 2              1      339.65  2020-07-06 15:30:00                   BUY
# 3              1      332.35  2020-07-06 10:00:00                  SELL
# 4              1       333.5  2020-07-03 13:00:00                   BUY
# 5              1      334.45  2020-07-03 12:45:00                  SELL
# 6              1       330.8  2020-07-03 10:00:00                   BUY
# 7              1       322.6  2020-07-01 15:30:00                  SELL
#
#   exit_quantity exit_price pnl_absolute pnl_percentage  \
# 0             1      331.0         -1.7          -0.52
# 1             1     329.25        -3.35          -1.01
# 2             1     338.85          0.8           0.24
# 3             1     335.65          3.3           0.99
# 4             1     330.15         3.35            1.0
# 5             1      333.5        -0.95          -0.28
# 6             1      334.1         -3.3           -1.0
# 7             1      324.1          1.5           0.46
#
#   pnl_cumulative_absolute pnl_cumulative_percentage
# 0                   -0.35                     -0.12
# 1                    1.35                       0.4
# 2                     4.7                      1.41
# 3                     3.9                      1.17
# 4                     0.6                      0.18
# 5                   -2.75                     -0.82
# 6                    -1.8                     -0.54
# 7                     1.5                      0.46

# %% [markdown]
# ### Recipe 11: MACD-Bracket-Order Strategy: Fetching Backtesting Reports - Statistics Table

# %%
algobulls_connection.get_backtesting_report_statistics(strategy_code2)
# Out:
#                    highlight_type highlight_value
# 0                         Net PnL           -0.35
# 1                       Net PnL %           -0.12
# 2                    Max Drawdown           -2.75
# 3                  Max Drawdown %           -0.82
# 4                Number of Trades               8
# 5                  Number of Wins               4
# 6                Number of Looses               4
# 7           Number of Long Trades               4
# 8          Number of Short Trades               4
# 9                        Max Gain            3.35
# 10                       Min Gain           -3.35
# 11  Avg. Profit per winning trade            2.24
# 12   Avg. Profit per losing trade           -2.32

# %% [markdown]
# ### Recipe 12: MACD-Bracket-Order Strategy: Fetching Backtesting Reports - Order History

# %%
order_history = algobulls_connection.get_backtesting_report_order_history(strategy_code2)
print(order_history)
# Out:
# +------------------+---------------------+----------------------------------+------+
# | INST             | TIME                | ID                               | TT   |
# |------------------+---------------------+----------------------------------+------|
# | NSE_EQ:TATASTEEL | 2020-07-01 12:30:00 | 1cbefcf395c344c88a228a1b01c32ef6 | BUY  |
# +------------------+---------------------+----------------------------------+------+
# +----+---------------------+------------------------+-------+
# |    | TIME                | STATE                  | MSG   |
# |----+---------------------+------------------------+-------|
# |  0 | 2020-07-01 12:30:00 | PUT ORDER REQ RECEIVED |       |
# |  1 | 2020-07-01 12:30:00 | VALIDATION PENDING     |       |
# |  2 | 2020-07-01 12:30:00 | OPEN PENDING           |       |
# |  3 | 2020-07-01 12:30:00 | OPEN                   |       |
# |  4 | 2020-07-01 12:30:00 | COMPLETE               |       |
# +----+---------------------+------------------------+-------+
#
# +------------------+---------------------+----------------------------------+------+
# | INST             | TIME                | ID                               | TT   |
# |------------------+---------------------+----------------------------------+------|
# | NSE_EQ:TATASTEEL | 2020-07-01 12:45:00 | fb8be91cdc8e4d4f9c5f5ab9f7bf8934 | SELL |
# +------------------+---------------------+----------------------------------+------+
# +----+---------------------+------------------------+-------+
# |    | TIME                | STATE                  | MSG   |
# |----+---------------------+------------------------+-------|
# |  0 | 2020-07-01 12:45:00 | PUT ORDER REQ RECEIVED |       |
# |  1 | 2020-07-01 12:45:00 | VALIDATION PENDING     |       |
# |  2 | 2020-07-01 12:45:00 | OPEN PENDING           |       |
# |  3 | 2020-07-01 12:45:00 | OPEN                   |       |
# |  4 | 2020-07-01 15:30:00 | CANCEL PENDING         |       |
# |  5 | 2020-07-01 15:30:00 | CANCELLED              |       |
# +----+---------------------+------------------------+-------+
#
# +------------------+---------------------+----------------------------------+------+
# | INST             | TIME                | ID                               | TT   |
# |------------------+---------------------+----------------------------------+------|
# | NSE_EQ:TATASTEEL | 2020-07-01 12:45:00 | 972ffb502d1a4242ae9c1f5d16bdfc46 | SELL |
# +------------------+---------------------+----------------------------------+------+
# +----+---------------------+------------------------+-------+
# |    | TIME                | STATE                  | MSG   |
# |----+---------------------+------------------------+-------|
# |  0 | 2020-07-01 12:45:00 | PUT ORDER REQ RECEIVED |       |
# |  1 | 2020-07-01 12:45:00 | VALIDATION PENDING     |       |
# |  2 | 2020-07-01 12:45:00 | OPEN PENDING           |       |
# |  3 | 2020-07-01 12:45:00 | TRIGGER PENDING        |       |
# |  4 | 2020-07-01 15:30:00 | CANCEL PENDING         |       |
# |  5 | 2020-07-01 15:30:00 | CANCELLED              |       |
# +----+---------------------+------------------------+-------+
#
# +------------------+---------------------+----------------------------------+------+
# | INST             | TIME                | ID                               | TT   |
# |------------------+---------------------+----------------------------------+------|
# | NSE_EQ:TATASTEEL | 2020-07-01 15:30:00 | c0d024b6a3be41f6a22efc826a8729aa | SELL |
# +------------------+---------------------+----------------------------------+------+
# +----+---------------------+------------------------+-------+
# |    | TIME                | STATE                  | MSG   |
# |----+---------------------+------------------------+-------|
# |  0 | 2020-07-01 15:30:00 | PUT ORDER REQ RECEIVED |       |
# |  1 | 2020-07-01 15:30:00 | VALIDATION PENDING     |       |
# |  2 | 2020-07-01 15:30:00 | OPEN PENDING           |       |
# |  3 | 2020-07-01 15:30:00 | OPEN                   |       |
# |  4 | 2020-07-01 15:30:00 | COMPLETE               |       |
# +----+---------------------+------------------------+-------+
#
# +------------------+---------------------+----------------------------------+------+
# | INST             | TIME                | ID                               | TT   |
# |------------------+---------------------+----------------------------------+------|
# | NSE_EQ:TATASTEEL | 2020-07-03 09:45:00 | ea5a4c6c63524f39a53de71f269ee256 | SELL |
# +------------------+---------------------+----------------------------------+------+
# +----+---------------------+------------------------+-------+
# |    | TIME                | STATE                  | MSG   |
# |----+---------------------+------------------------+-------|
# |  0 | 2020-07-03 09:45:00 | PUT ORDER REQ RECEIVED |       |
# |  1 | 2020-07-03 09:45:00 | VALIDATION PENDING     |       |
# |  2 | 2020-07-03 09:45:00 | OPEN PENDING           |       |
# |  3 | 2020-07-03 09:45:00 | OPEN                   |       |
# |  4 | 2020-07-03 09:45:00 | COMPLETE               |       |
# +----+---------------------+------------------------+-------+
#
# +------------------+---------------------+----------------------------------+------+
# | INST             | TIME                | ID                               | TT   |
# |------------------+---------------------+----------------------------------+------|
# | NSE_EQ:TATASTEEL | 2020-07-03 10:00:00 | 03436b72ad8a47a8b29bb727876b0b95 | BUY  |
# +------------------+---------------------+----------------------------------+------+
# +----+---------------------+------------------------+-------+
# |    | TIME                | STATE                  | MSG   |
# |----+---------------------+------------------------+-------|
# |  0 | 2020-07-03 10:00:00 | PUT ORDER REQ RECEIVED |       |
# |  1 | 2020-07-03 10:00:00 | VALIDATION PENDING     |       |
# |  2 | 2020-07-03 10:00:00 | OPEN PENDING           |       |
# |  3 | 2020-07-03 10:00:00 | TRIGGER PENDING        |       |
# |  4 | 2020-07-03 12:30:00 | OPEN                   |       |
# |  5 | 2020-07-03 12:30:00 | COMPLETE               |       |
# +----+---------------------+------------------------+-------+
#
# +------------------+---------------------+----------------------------------+------+
# | INST             | TIME                | ID                               | TT   |
# |------------------+---------------------+----------------------------------+------|
# | NSE_EQ:TATASTEEL | 2020-07-03 10:00:00 | 62458cf47d5f4a12b6c31c490451fdb0 | BUY  |
# +------------------+---------------------+----------------------------------+------+
# +----+---------------------+------------------------+-------+
# |    | TIME                | STATE                  | MSG   |
# |----+---------------------+------------------------+-------|
# |  0 | 2020-07-03 10:00:00 | PUT ORDER REQ RECEIVED |       |
# |  1 | 2020-07-03 10:00:00 | VALIDATION PENDING     |       |
# |  2 | 2020-07-03 10:00:00 | OPEN PENDING           |       |
# |  3 | 2020-07-03 10:00:00 | OPEN                   |       |
# |  4 | 2020-07-03 12:30:00 | CANCEL PENDING         |       |
# |  5 | 2020-07-03 12:30:00 | CANCELLED              |       |
# +----+---------------------+------------------------+-------+
#
# +------------------+---------------------+----------------------------------+------+
# | INST             | TIME                | ID                               | TT   |
# |------------------+---------------------+----------------------------------+------|
# | NSE_EQ:TATASTEEL | 2020-07-03 12:30:00 | a88484f7888f496e801515ff400f69ea | BUY  |
# +------------------+---------------------+----------------------------------+------+
# +----+---------------------+------------------------+-------+
# |    | TIME                | STATE                  | MSG   |
# |----+---------------------+------------------------+-------|
# |  0 | 2020-07-03 12:30:00 | PUT ORDER REQ RECEIVED |       |
# |  1 | 2020-07-03 12:30:00 | VALIDATION PENDING     |       |
# |  2 | 2020-07-03 12:30:00 | OPEN PENDING           |       |
# |  3 | 2020-07-03 12:30:00 | OPEN                   |       |
# |  4 | 2020-07-03 12:30:00 | COMPLETE               |       |
# +----+---------------------+------------------------+-------+
#
# +------------------+---------------------+----------------------------------+------+
# | INST             | TIME                | ID                               | TT   |
# |------------------+---------------------+----------------------------------+------|
# | NSE_EQ:TATASTEEL | 2020-07-03 12:45:00 | f3c96875a80f41acb4c344febbc6cb43 | SELL |
# +------------------+---------------------+----------------------------------+------+
# +----+---------------------+------------------------+-------+
# |    | TIME                | STATE                  | MSG   |
# |----+---------------------+------------------------+-------|
# |  0 | 2020-07-03 12:45:00 | PUT ORDER REQ RECEIVED |       |
# |  1 | 2020-07-03 12:45:00 | VALIDATION PENDING     |       |
# |  2 | 2020-07-03 12:45:00 | OPEN PENDING           |       |
# |  3 | 2020-07-03 12:45:00 | OPEN                   |       |
# |  4 | 2020-07-03 12:45:00 | CANCEL PENDING         |       |
# |  5 | 2020-07-03 12:45:00 | CANCELLED              |       |
# +----+---------------------+------------------------+-------+
#
# +------------------+---------------------+----------------------------------+------+
# | INST             | TIME                | ID                               | TT   |
# |------------------+---------------------+----------------------------------+------|
# | NSE_EQ:TATASTEEL | 2020-07-03 12:45:00 | 9a7b474106e549f084bb94dfe7686588 | SELL |
# +------------------+---------------------+----------------------------------+------+
# +----+---------------------+------------------------+-------+
# |    | TIME                | STATE                  | MSG   |
# |----+---------------------+------------------------+-------|
# |  0 | 2020-07-03 12:45:00 | PUT ORDER REQ RECEIVED |       |
# |  1 | 2020-07-03 12:45:00 | VALIDATION PENDING     |       |
# |  2 | 2020-07-03 12:45:00 | OPEN PENDING           |       |
# |  3 | 2020-07-03 12:45:00 | TRIGGER PENDING        |       |
# |  4 | 2020-07-03 12:45:00 | CANCEL PENDING         |       |
# |  5 | 2020-07-03 12:45:00 | CANCELLED              |       |
# +----+---------------------+------------------------+-------+
#
# +------------------+---------------------+----------------------------------+------+
# | INST             | TIME                | ID                               | TT   |
# |------------------+---------------------+----------------------------------+------|
# | NSE_EQ:TATASTEEL | 2020-07-03 12:45:00 | 1dab5ff3edb046918fe45d43f189341e | SELL |
# +------------------+---------------------+----------------------------------+------+
# +----+---------------------+------------------------+-------+
# |    | TIME                | STATE                  | MSG   |
# |----+---------------------+------------------------+-------|
# |  0 | 2020-07-03 12:45:00 | PUT ORDER REQ RECEIVED |       |
# |  1 | 2020-07-03 12:45:00 | VALIDATION PENDING     |       |
# |  2 | 2020-07-03 12:45:00 | OPEN PENDING           |       |
# |  3 | 2020-07-03 12:45:00 | OPEN                   |       |
# |  4 | 2020-07-03 12:45:00 | COMPLETE               |       |
# +----+---------------------+------------------------+-------+
#
# +------------------+---------------------+----------------------------------+------+
# | INST             | TIME                | ID                               | TT   |
# |------------------+---------------------+----------------------------------+------|
# | NSE_EQ:TATASTEEL | 2020-07-03 12:45:00 | 32948c0159da4481891bd29daec2ff0a | SELL |
# +------------------+---------------------+----------------------------------+------+
# +----+---------------------+------------------------+-------+
# |    | TIME                | STATE                  | MSG   |
# |----+---------------------+------------------------+-------|
# |  0 | 2020-07-03 12:45:00 | PUT ORDER REQ RECEIVED |       |
# |  1 | 2020-07-03 12:45:00 | VALIDATION PENDING     |       |
# |  2 | 2020-07-03 12:45:00 | OPEN PENDING           |       |
# |  3 | 2020-07-03 12:45:00 | OPEN                   |       |
# |  4 | 2020-07-03 12:45:00 | COMPLETE               |       |
# +----+---------------------+------------------------+-------+
#
# +------------------+---------------------+----------------------------------+------+
# | INST             | TIME                | ID                               | TT   |
# |------------------+---------------------+----------------------------------+------|
# | NSE_EQ:TATASTEEL | 2020-07-03 13:00:00 | 6f1fdd54207f499aae0d71ba41a94891 | BUY  |
# +------------------+---------------------+----------------------------------+------+
# +----+---------------------+------------------------+-------+
# |    | TIME                | STATE                  | MSG   |
# |----+---------------------+------------------------+-------|
# |  0 | 2020-07-03 13:00:00 | PUT ORDER REQ RECEIVED |       |
# |  1 | 2020-07-03 13:00:00 | VALIDATION PENDING     |       |
# |  2 | 2020-07-03 13:00:00 | OPEN PENDING           |       |
# |  3 | 2020-07-03 13:00:00 | OPEN                   |       |
# |  4 | 2020-07-03 14:45:00 | COMPLETE               |       |
# +----+---------------------+------------------------+-------+
#
# +------------------+---------------------+----------------------------------+------+
# | INST             | TIME                | ID                               | TT   |
# |------------------+---------------------+----------------------------------+------|
# | NSE_EQ:TATASTEEL | 2020-07-03 13:00:00 | 446a3850abf145288dff03854fa20ec3 | BUY  |
# +------------------+---------------------+----------------------------------+------+
# +----+---------------------+------------------------+-------+
# |    | TIME                | STATE                  | MSG   |
# |----+---------------------+------------------------+-------|
# |  0 | 2020-07-03 13:00:00 | PUT ORDER REQ RECEIVED |       |
# |  1 | 2020-07-03 13:00:00 | VALIDATION PENDING     |       |
# |  2 | 2020-07-03 13:00:00 | OPEN PENDING           |       |
# |  3 | 2020-07-03 13:00:00 | TRIGGER PENDING        |       |
# |  4 | 2020-07-03 14:45:00 | CANCEL PENDING         |       |
# |  5 | 2020-07-03 14:45:00 | CANCELLED              |       |
# +----+---------------------+------------------------+-------+
#
# +------------------+---------------------+----------------------------------+------+
# | INST             | TIME                | ID                               | TT   |
# |------------------+---------------------+----------------------------------+------|
# | NSE_EQ:TATASTEEL | 2020-07-06 09:45:00 | 0f4ae537fdf643f2901eeb4aa3bc4a0f | BUY  |
# +------------------+---------------------+----------------------------------+------+
# +----+---------------------+------------------------+-------+
# |    | TIME                | STATE                  | MSG   |
# |----+---------------------+------------------------+-------|
# |  0 | 2020-07-06 09:45:00 | PUT ORDER REQ RECEIVED |       |
# |  1 | 2020-07-06 09:45:00 | VALIDATION PENDING     |       |
# |  2 | 2020-07-06 09:45:00 | OPEN PENDING           |       |
# |  3 | 2020-07-06 09:45:00 | OPEN                   |       |
# |  4 | 2020-07-06 09:45:00 | COMPLETE               |       |
# +----+---------------------+------------------------+-------+
#
# +------------------+---------------------+----------------------------------+------+
# | INST             | TIME                | ID                               | TT   |
# |------------------+---------------------+----------------------------------+------|
# | NSE_EQ:TATASTEEL | 2020-07-06 10:00:00 | 5acd4ba4137243978efd9aec9054c329 | SELL |
# +------------------+---------------------+----------------------------------+------+
# +----+---------------------+------------------------+-------+
# |    | TIME                | STATE                  | MSG   |
# |----+---------------------+------------------------+-------|
# |  0 | 2020-07-06 10:00:00 | PUT ORDER REQ RECEIVED |       |
# |  1 | 2020-07-06 10:00:00 | VALIDATION PENDING     |       |
# |  2 | 2020-07-06 10:00:00 | OPEN PENDING           |       |
# |  3 | 2020-07-06 10:00:00 | OPEN                   |       |
# |  4 | 2020-07-06 10:15:00 | COMPLETE               |       |
# +----+---------------------+------------------------+-------+
#
# +------------------+---------------------+----------------------------------+------+
# | INST             | TIME                | ID                               | TT   |
# |------------------+---------------------+----------------------------------+------|
# | NSE_EQ:TATASTEEL | 2020-07-06 10:00:00 | 8e03fe4428954257af26ee042debd62e | SELL |
# +------------------+---------------------+----------------------------------+------+
# +----+---------------------+------------------------+-------+
# |    | TIME                | STATE                  | MSG   |
# |----+---------------------+------------------------+-------|
# |  0 | 2020-07-06 10:00:00 | PUT ORDER REQ RECEIVED |       |
# |  1 | 2020-07-06 10:00:00 | VALIDATION PENDING     |       |
# |  2 | 2020-07-06 10:00:00 | OPEN PENDING           |       |
# |  3 | 2020-07-06 10:00:00 | TRIGGER PENDING        |       |
# |  4 | 2020-07-06 10:15:00 | CANCEL PENDING         |       |
# |  5 | 2020-07-06 10:15:00 | CANCELLED              |       |
# +----+---------------------+------------------------+-------+
#
# +------------------+---------------------+----------------------------------+------+
# | INST             | TIME                | ID                               | TT   |
# |------------------+---------------------+----------------------------------+------|
# | NSE_EQ:TATASTEEL | 2020-07-06 13:30:00 | b0400fc8e77941f8b72ace6bc3d53bca | SELL |
# +------------------+---------------------+----------------------------------+------+
# +----+---------------------+------------------------+-------+
# |    | TIME                | STATE                  | MSG   |
# |----+---------------------+------------------------+-------|
# |  0 | 2020-07-06 13:30:00 | PUT ORDER REQ RECEIVED |       |
# |  1 | 2020-07-06 13:30:00 | VALIDATION PENDING     |       |
# |  2 | 2020-07-06 13:30:00 | OPEN PENDING           |       |
# |  3 | 2020-07-06 13:30:00 | OPEN                   |       |
# |  4 | 2020-07-06 13:30:00 | COMPLETE               |       |
# +----+---------------------+------------------------+-------+
#
# +------------------+---------------------+----------------------------------+------+
# | INST             | TIME                | ID                               | TT   |
# |------------------+---------------------+----------------------------------+------|
# | NSE_EQ:TATASTEEL | 2020-07-06 13:45:00 | 7d8525013a694cdd81be74755037d7c0 | BUY  |
# +------------------+---------------------+----------------------------------+------+
# +----+---------------------+------------------------+-------+
# |    | TIME                | STATE                  | MSG   |
# |----+---------------------+------------------------+-------|
# |  0 | 2020-07-06 13:45:00 | PUT ORDER REQ RECEIVED |       |
# |  1 | 2020-07-06 13:45:00 | VALIDATION PENDING     |       |
# |  2 | 2020-07-06 13:45:00 | OPEN PENDING           |       |
# |  3 | 2020-07-06 13:45:00 | OPEN                   |       |
# |  4 | 2020-07-06 15:30:00 | CANCEL PENDING         |       |
# |  5 | 2020-07-06 15:30:00 | CANCELLED              |       |
# +----+---------------------+------------------------+-------+
#
# +------------------+---------------------+----------------------------------+------+
# | INST             | TIME                | ID                               | TT   |
# |------------------+---------------------+----------------------------------+------|
# | NSE_EQ:TATASTEEL | 2020-07-06 13:45:00 | 984310d2323541c8a5d0b5303ab40bad | BUY  |
# +------------------+---------------------+----------------------------------+------+
# +----+---------------------+------------------------+-------+
# |    | TIME                | STATE                  | MSG   |
# |----+---------------------+------------------------+-------|
# |  0 | 2020-07-06 13:45:00 | PUT ORDER REQ RECEIVED |       |
# |  1 | 2020-07-06 13:45:00 | VALIDATION PENDING     |       |
# |  2 | 2020-07-06 13:45:00 | OPEN PENDING           |       |
# |  3 | 2020-07-06 13:45:00 | TRIGGER PENDING        |       |
# |  4 | 2020-07-06 15:30:00 | CANCEL PENDING         |       |
# |  5 | 2020-07-06 15:30:00 | CANCELLED              |       |
# +----+---------------------+------------------------+-------+
#
# +------------------+---------------------+----------------------------------+------+
# | INST             | TIME                | ID                               | TT   |
# |------------------+---------------------+----------------------------------+------|
# | NSE_EQ:TATASTEEL | 2020-07-06 15:30:00 | f1c18daa21904a4abe92dc4d56574719 | BUY  |
# +------------------+---------------------+----------------------------------+------+
# +----+---------------------+------------------------+-------+
# |    | TIME                | STATE                  | MSG   |
# |----+---------------------+------------------------+-------|
# |  0 | 2020-07-06 15:30:00 | PUT ORDER REQ RECEIVED |       |
# |  1 | 2020-07-06 15:30:00 | VALIDATION PENDING     |       |
# |  2 | 2020-07-06 15:30:00 | OPEN PENDING           |       |
# |  3 | 2020-07-06 15:30:00 | OPEN                   |       |
# |  4 | 2020-07-06 15:30:00 | COMPLETE               |       |
# +----+---------------------+------------------------+-------+
#
# +------------------+---------------------+----------------------------------+------+
# | INST             | TIME                | ID                               | TT   |
# |------------------+---------------------+----------------------------------+------|
# | NSE_EQ:TATASTEEL | 2020-07-07 13:15:00 | 311caaf7d5564030be54069c0998a7e4 | BUY  |
# +------------------+---------------------+----------------------------------+------+
# +----+---------------------+------------------------+-------+
# |    | TIME                | STATE                  | MSG   |
# |----+---------------------+------------------------+-------|
# |  0 | 2020-07-07 13:15:00 | PUT ORDER REQ RECEIVED |       |
# |  1 | 2020-07-07 13:15:00 | VALIDATION PENDING     |       |
# |  2 | 2020-07-07 13:15:00 | OPEN PENDING           |       |
# |  3 | 2020-07-07 13:15:00 | OPEN                   |       |
# |  4 | 2020-07-07 13:15:00 | COMPLETE               |       |
# +----+---------------------+------------------------+-------+
#
# +------------------+---------------------+----------------------------------+------+
# | INST             | TIME                | ID                               | TT   |
# |------------------+---------------------+----------------------------------+------|
# | NSE_EQ:TATASTEEL | 2020-07-07 13:30:00 | e228d5c2165048eebc28db14e428c200 | SELL |
# +------------------+---------------------+----------------------------------+------+
# +----+---------------------+------------------------+-------+
# |    | TIME                | STATE                  | MSG   |
# |----+---------------------+------------------------+-------|
# |  0 | 2020-07-07 13:30:00 | PUT ORDER REQ RECEIVED |       |
# |  1 | 2020-07-07 13:30:00 | VALIDATION PENDING     |       |
# |  2 | 2020-07-07 13:30:00 | OPEN PENDING           |       |
# |  3 | 2020-07-07 13:30:00 | TRIGGER PENDING        |       |
# |  4 | 2020-07-07 14:45:00 | OPEN                   |       |
# |  5 | 2020-07-07 14:45:00 | COMPLETE               |       |
# +----+---------------------+------------------------+-------+
#
# +------------------+---------------------+----------------------------------+------+
# | INST             | TIME                | ID                               | TT   |
# |------------------+---------------------+----------------------------------+------|
# | NSE_EQ:TATASTEEL | 2020-07-07 13:30:00 | 1d2d37f3a4004907a44948eb74bf5e6d | SELL |
# +------------------+---------------------+----------------------------------+------+
# +----+---------------------+------------------------+-------+
# |    | TIME                | STATE                  | MSG   |
# |----+---------------------+------------------------+-------|
# |  0 | 2020-07-07 13:30:00 | PUT ORDER REQ RECEIVED |       |
# |  1 | 2020-07-07 13:30:00 | VALIDATION PENDING     |       |
# |  2 | 2020-07-07 13:30:00 | OPEN PENDING           |       |
# |  3 | 2020-07-07 13:30:00 | OPEN                   |       |
# |  4 | 2020-07-07 14:45:00 | CANCEL PENDING         |       |
# |  5 | 2020-07-07 14:45:00 | CANCELLED              |       |
# +----+---------------------+------------------------+-------+
#
# +------------------+---------------------+----------------------------------+------+
# | INST             | TIME                | ID                               | TT   |
# |------------------+---------------------+----------------------------------+------|
# | NSE_EQ:TATASTEEL | 2020-07-07 14:45:00 | b5c5a86c76fb4f7f845ac7d9087501ae | SELL |
# +------------------+---------------------+----------------------------------+------+
# +----+---------------------+------------------------+-------+
# |    | TIME                | STATE                  | MSG   |
# |----+---------------------+------------------------+-------|
# |  0 | 2020-07-07 14:45:00 | PUT ORDER REQ RECEIVED |       |
# |  1 | 2020-07-07 14:45:00 | VALIDATION PENDING     |       |
# |  2 | 2020-07-07 14:45:00 | OPEN PENDING           |       |
# |  3 | 2020-07-07 14:45:00 | OPEN                   |       |
# |  4 | 2020-07-07 14:45:00 | COMPLETE               |       |
# +----+---------------------+------------------------+-------+
#
# +------------------+---------------------+----------------------------------+------+
# | INST             | TIME                | ID                               | TT   |
# |------------------+---------------------+----------------------------------+------|
# | NSE_EQ:TATASTEEL | 2020-07-07 15:00:00 | 36a1bd24bcf7461584e5d28038dcb44a | BUY  |
# +------------------+---------------------+----------------------------------+------+
# +----+---------------------+------------------------+-------+
# |    | TIME                | STATE                  | MSG   |
# |----+---------------------+------------------------+-------|
# |  0 | 2020-07-07 15:00:00 | PUT ORDER REQ RECEIVED |       |
# |  1 | 2020-07-07 15:00:00 | VALIDATION PENDING     |       |
# |  2 | 2020-07-07 15:00:00 | OPEN PENDING           |       |
# |  3 | 2020-07-07 15:00:00 | OPEN                   |       |
# |  4 | 2020-07-07 15:30:00 | CANCEL PENDING         |       |
# |  5 | 2020-07-07 15:30:00 | CANCELLED              |       |
# +----+---------------------+------------------------+-------+
#
# +------------------+---------------------+----------------------------------+------+
# | INST             | TIME                | ID                               | TT   |
# |------------------+---------------------+----------------------------------+------|
# | NSE_EQ:TATASTEEL | 2020-07-07 15:00:00 | 5ebd84229f364d92b380c531d2110bd9 | BUY  |
# +------------------+---------------------+----------------------------------+------+
# +----+---------------------+------------------------+-------+
# |    | TIME                | STATE                  | MSG   |
# |----+---------------------+------------------------+-------|
# |  0 | 2020-07-07 15:00:00 | PUT ORDER REQ RECEIVED |       |
# |  1 | 2020-07-07 15:00:00 | VALIDATION PENDING     |       |
# |  2 | 2020-07-07 15:00:00 | OPEN PENDING           |       |
# |  3 | 2020-07-07 15:00:00 | TRIGGER PENDING        |       |
# |  4 | 2020-07-07 15:30:00 | CANCEL PENDING         |       |
# |  5 | 2020-07-07 15:30:00 | CANCELLED              |       |
# +----+---------------------+------------------------+-------+
#
# +------------------+---------------------+----------------------------------+------+
# | INST             | TIME                | ID                               | TT   |
# |------------------+---------------------+----------------------------------+------|
# | NSE_EQ:TATASTEEL | 2020-07-07 15:30:00 | a614b94300cd4d8f8dbbebfca00a8065 | BUY  |
# +------------------+---------------------+----------------------------------+------+
# +----+---------------------+------------------------+-------+
# |    | TIME                | STATE                  | MSG   |
# |----+---------------------+------------------------+-------|
# |  0 | 2020-07-07 15:30:00 | PUT ORDER REQ RECEIVED |       |
# |  1 | 2020-07-07 15:30:00 | VALIDATION PENDING     |       |
# |  2 | 2020-07-07 15:30:00 | OPEN PENDING           |       |
# |  3 | 2020-07-07 15:30:00 | OPEN                   |       |
# |  4 | 2020-07-07 15:30:00 | COMPLETE               |       |
# +----+---------------------+------------------------+-------+
